# %% [markdown]
# <a href="https://colab.research.google.com/github/Lily1619/Fire-Rescue-Robot/blob/main/Workng_real_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.signal as sg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
np.load("/content/drive/MyDrive/datasets/dsp_datasets/arrhythmia_preprocessed/100_1.npy")
# Out:
# array([-0.03720375, -0.04355592, -0.03254148, ...,  0.00841994,
#         0.00907958, -0.00280602])

# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.25.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.0.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2024.2.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2

# %%
import wfdb

# %%
direct = "/content/drive/MyDrive/datasets/dsp_datasets/arrhythmia/100"
record = wfdb.rdrecord(direct)

# %%
direct_2 = "/content/drive/MyDrive/datasets/dsp_datasets/atrial/04043"
record_2 = wfdb.rdrecord(direct_2)

# %%
direct_3 = "/content/drive/MyDrive/datasets/dsp_datasets/supra/800"
record_3 = wfdb.rdrecord(direct_3)

# %%
sampling = record_3.fs
sampling
# Out:
# 128

# %%
signal = record.p_signal
signal = signal[:,0]

# %%
sampling = record.fs
sampling
# Out:
# 360

# %%
sampling = record_2.fs
sampling
# Out:
# 250

# %%
plt.plot(signal[:1000])

# %%
direct_1 = "/content/drive/MyDrive/datasets/dsp_datasets"

# %%
classes = os.listdir(direct_1)
print(classes)
# Out:
# ['supra', 'arrhythmia', 'atrial', 'atrial_preprocessed', 'arrhythmia_preprocessed', 'supra_preprocessed']

# %%
def resample_signal(signal, original_sampling_rate, target_sampling_rate):
    resampling_factor = target_sampling_rate / original_sampling_rate
    num_samples_resampled = int(len(signal) * resampling_factor)
    resampled_signal = sg.resample(signal, num_samples_resampled)
    return resampled_signal

# %%
def preprocessing_arrh(input_signal, record):
    # Split the input signal into blocks
    block_size = 1280
    num_blocks = len(input_signal) // block_size

    processed_data = []

    for i in range(num_blocks):
        block_start = i * block_size
        block_end = (i + 1) * block_size
        block = input_signal[block_start:block_end]

        # Mean removal
        block = block - np.mean(block)

        # Low-pass filtering
        block = sg.filtfilt(*sg.butter(4, 0.9, btype='low'), block)

        # High-pass filtering (baseline wander removal)
        block = sg.filtfilt(*sg.butter(4, 0.0039, btype='high'), block)

        # Normalization
        block = block / np.max(np.abs(block))

        np.save(f"/content/drive/MyDrive/datasets/dsp_datasets/arrhythmia_preprocessed/{record}_{i}.npy", block)

# %%
# Path to the directory containing .dat files
dat_dir_arrhythmia = "/content/drive/MyDrive/datasets/dsp_datasets/arrhythmia/"
dat_dir_supra = "/content/drive/MyDrive/datasets/dsp_datasets/supra/"
dat_dir_atrial = "/content/drive/MyDrive/datasets/dsp_datasets/atrial/"

# Path to the directory to store preprocessed data
output_dir_arrhythmia = "/content/drive/MyDrive/datasets/dsp_datasets/arrhythmia_preprocessed/"
original_sampling_rate_arrhythmia = 360  # Adjust as needed
output_dir_supra = "/content/drive/MyDrive/datasets/dsp_datasets/supra_preprocessed/"
original_sampling_rate_supra = 128  # Adjust as needed
output_dir_atrial = "/content/drive/MyDrive/datasets/dsp_datasets/atrial_preprocessed/"
original_sampling_rate_atrial = 250  # Adjust as needed
# Target sampling rate after resampling
target_sampling_rate = 128  # Adjust as needed

# %%
# Iterate over each .dat file in the directory
a=0
for filename in os.listdir(dat_dir_arrhythmia):
    if filename.endswith(".dat"):
        filepath = os.path.join(dat_dir_arrhythmia, filename)

        # Load the signal using wfdb
        record = wfdb.rdrecord(filepath[:-4])
        signals = record.p_signal  # Extract the signals
        signal = signals[:,0]

        # Original sampling rate
        original_sampling_rate = record.fs

        resampled_signal = resample_signal(signal, original_sampling_rate, target_sampling_rate)

        # Preprocess the resampled signal
        preprocessed_data = preprocessing_arrh(resampled_signal, filename[:3])
        print(a)
        a+=1

# %%
def preprocessing_supra(input_signal, record):
    # Split the input signal into blocks
    block_size = 1280
    num_blocks = len(input_signal) // block_size

    processed_data = []

    for i in range(num_blocks):
        block_start = i * block_size
        block_end = (i + 1) * block_size
        block = input_signal[block_start:block_end]

        # Mean removal
        block = block - np.mean(block)

        # Low-pass filtering
        block = sg.filtfilt(*sg.butter(4, 0.9, btype='low'), block)

        # High-pass filtering (baseline wander removal)
        block = sg.filtfilt(*sg.butter(4, 0.0039, btype='high'), block)

        # Normalization
        block = block / np.max(np.abs(block))

        np.save(f"/content/drive/MyDrive/datasets/dsp_datasets/supra_preprocessed/{record}_{i}.npy", block)

# %%
# Iterate over each .dat file in the directory
b=0
for filename in os.listdir(dat_dir_supra):
    if filename.endswith(".dat"):
        filepath = os.path.join(dat_dir_supra, filename)

        # Load the signal using wfdb
        record = wfdb.rdrecord(filepath[:-4])
        signals = record.p_signal  # Extract the signals
        signal = signals[:,0]

        # Original sampling rate
        original_sampling_rate = record.fs

        resampled_signal = resample_signal(signal, original_sampling_rate, target_sampling_rate)

        # Preprocess the resampled signal
        preprocessed_data = preprocessing_supra(resampled_signal, filename[:3])
        print(b)
        b+=1

# %%
def preprocessing(input_signal, record):
    # Split the input signal into blocks
    block_size = 1280
    num_blocks = len(input_signal) // block_size

    processed_data_atrial = []

    for i in range(num_blocks):
        block_start = i * block_size
        block_end = (i + 1) * block_size
        block = input_signal[block_start:block_end]

        # Mean removal
        block = block - np.mean(block)

        # Low-pass filtering
        block = sg.filtfilt(*sg.butter(4, 0.9, btype='low'), block)

        # High-pass filtering (baseline wander removal)
        block = sg.filtfilt(*sg.butter(4, 0.0039, btype='high'), block)

        # Normalization
        block = block / np.max(np.abs(block))

        np.save(f"/content/drive/MyDrive/datasets/dsp_datasets/atrial_preprocessed/{record}_{i}.npy", block)

# %%
# Iterate over each .dat file in the directory
c=0
for filename in os.listdir(dat_dir_atrial):
    if filename.endswith(".dat"):
        filepath = os.path.join(dat_dir_atrial, filename)

        # Load the signal using wfdb
        record = wfdb.rdrecord(filepath[:-4])
        signals = record.p_signal  # Extract the signals
        signal = signals[:,0]

        # Original sampling rate
        original_sampling_rate = record.fs

        resampled_signal = resample_signal(signal, original_sampling_rate, target_sampling_rate)

        # Preprocess the resampled signal
        preprocessed_data = preprocessing(resampled_signal, filename[:5])
        print(c)
        c+=1

# %%
np.load("/content/drive/MyDrive/datasets/dsp_datasets/supra_preprocessed/826_0.npy").shape
# Out:
# (1280,)

# %%
import os
import numpy as np

# Define your classes list and dataset directory
classes_list = ['arrhythmia_preprocessed', 'atrial_preprocessed', 'supra_preprocessed']  # Replace with your class names
datasetDir = "/content/drive/MyDrive/datasets/dsp_datasets"  # Replace with your dataset directory
save_dir = "/content/drive/MyDrive/datasets"  # Directory to save the dataset

def create_dataset():
    features = []
    labels = []

    # Define the target number of files to load for each class
    target_num_files_per_class = 2000

    total_files_loaded = 0

    for class_index, class_name in enumerate(classes_list):
        class_files_list = os.listdir(os.path.join(datasetDir, class_name))
        num_files_to_load = min(target_num_files_per_class, len(class_files_list))

        print("Loading files for class:", class_name)
        print("Total files available:", len(class_files_list))
        print("Target files to load:", num_files_to_load)

        for file_index, file_name in enumerate(class_files_list[:num_files_to_load], start=1):
            signal_file_path = os.path.join(datasetDir, class_name, file_name)
            array_data = np.load(signal_file_path)

            features.append(array_data)
            labels.append(class_index)

            total_files_loaded += 1
            print("Files loaded:", total_files_loaded, "/", 5999)

            if total_files_loaded >= 5999:
                break  # Stop loading files once 7499 files are loaded

        if total_files_loaded >= 5999:
            break  # Stop loading files from other classes once 4499 files are loaded

    features = np.asarray(features)
    labels = np.asarray(labels)

    # Save the dataset
    np.save(os.path.join(save_dir, 'features.npy'), features)
    np.save(os.path.join(save_dir, 'labels.npy'), labels)

    return features, labels

# Create the dataset
features, labels = create_dataset()

# Now you have your features and labels ready for further processing or modeling
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# Files loaded: 1008 / 5999
# Files loaded: 1009 / 5999
# Files loaded: 1010 / 5999
# Files loaded: 1011 / 5999
# Files loaded: 1012 / 5999
# Files loaded: 1013 / 5999
# Files loaded: 1014 / 5999
# Files loaded: 1015 / 5999
# Files loaded: 1016 / 5999
# Files loaded: 1017 / 5999
# Files loaded: 1018 / 5999
# Files loaded: 1019 / 5999
# Files loaded: 1020 / 5999
# Files loaded: 1021 / 5999
# Files loaded: 1022 / 5999
# Files loaded: 1023 / 5999
# Files loaded: 1024 / 5999
# Files loaded: 1025 / 5999
# Files loaded: 1026 / 5999
# Files loaded: 1027 / 5999
# Files loaded: 1028 / 5999
# Files loaded: 1029 / 5999
# Files loaded: 1030 / 5999
# Files loaded: 1031 / 5999
# Files loaded: 1032 / 5999
# Files loaded: 1033 / 5999
# Files loaded: 1034 / 5999
# Files loaded: 1035 / 5999
# Files loaded: 1036 / 5999
# Files loaded: 1037 / 5999
# Files loaded: 1038 / 5999
# Files loaded: 1039 / 5999
# Files loaded: 1040 / 5999
# Files loaded: 1041 / 5999
# Files loaded: 1042 / 5999
# Files loaded: 1043 / 5999
# Files loaded: 1044 / 5999
# Files loaded: 1045 / 5999
# Files loaded: 1046 / 5999
# Files loaded: 1047 / 5999
# Files loaded: 1048 / 5999
# Files loaded: 1049 / 5999
# Files loaded: 1050 / 5999
# Files loaded: 1051 / 5999
# Files loaded: 1052 / 5999
# Files loaded: 1053 / 5999
# Files loaded: 1054 / 5999
# Files loaded: 1055 / 5999
# Files loaded: 1056 / 5999
# Files loaded: 1057 / 5999
# Files loaded: 1058 / 5999
# Files loaded: 1059 / 5999
# Files loaded: 1060 / 5999
# Files loaded: 1061 / 5999
# Files loaded: 1062 / 5999
# Files loaded: 1063 / 5999
# Files loaded: 1064 / 5999
# Files loaded: 1065 / 5999
# Files loaded: 1066 / 5999
# Files loaded: 1067 / 5999
# Files loaded: 1068 / 5999
# Files loaded: 1069 / 5999
# Files loaded: 1070 / 5999
# Files loaded: 1071 / 5999
# Files loaded: 1072 / 5999
# Files loaded: 1073 / 5999
# Files loaded: 1074 / 5999
# Files loaded: 1075 / 5999
# Files loaded: 1076 / 5999
# Files loaded: 1077 / 5999
# Files loaded: 1078 / 5999
# Files loaded: 1079 / 5999
# Files loaded: 1080 / 5999
# Files loaded: 1081 / 5999
# Files loaded: 1082 / 5999
# Files loaded: 1083 / 5999
# Files loaded: 1084 / 5999
# Files loaded: 1085 / 5999
# Files loaded: 1086 / 5999
# Files loaded: 1087 / 5999
# Files loaded: 1088 / 5999
# Files loaded: 1089 / 5999
# Files loaded: 1090 / 5999
# Files loaded: 1091 / 5999
# Files loaded: 1092 / 5999
# Files loaded: 1093 / 5999
# Files loaded: 1094 / 5999
# Files loaded: 1095 / 5999
# Files loaded: 1096 / 5999
# Files loaded: 1097 / 5999
# Files loaded: 1098 / 5999
# Files loaded: 1099 / 5999
# Files loaded: 1100 / 5999
# Files loaded: 1101 / 5999
# Files loaded: 1102 / 5999
# Files loaded: 1103 / 5999
# Files loaded: 1104 / 5999
# Files loaded: 1105 / 5999
# Files loaded: 1106 / 5999
# Files loaded: 1107 / 5999
# Files loaded: 1108 / 5999
# Files loaded: 1109 / 5999
# Files loaded: 1110 / 5999
# Files loaded: 1111 / 5999
# Files loaded: 1112 / 5999
# Files loaded: 1113 / 5999
# Files loaded: 1114 / 5999
# Files loaded: 1115 / 5999
# Files loaded: 1116 / 5999
# Files loaded: 1117 / 5999
# Files loaded: 1118 / 5999
# Files loaded: 1119 / 5999
# Files loaded: 1120 / 5999
# Files loaded: 1121 / 5999
# Files loaded: 1122 / 5999
# Files loaded: 1123 / 5999
# Files loaded: 1124 / 5999
# Files loaded: 1125 / 5999
# Files loaded: 1126 / 5999
# Files loaded: 1127 / 5999
# Files loaded: 1128 / 5999
# Files loaded: 1129 / 5999
# Files loaded: 1130 / 5999
# Files loaded: 1131 / 5999
# Files loaded: 1132 / 5999
# Files loaded: 1133 / 5999
# Files loaded: 1134 / 5999
# Files loaded: 1135 / 5999
# Files loaded: 1136 / 5999
# Files loaded: 1137 / 5999
# Files loaded: 1138 / 5999
# Files loaded: 1139 / 5999
# Files loaded: 1140 / 5999
# Files loaded: 1141 / 5999
# Files loaded: 1142 / 5999
# Files loaded: 1143 / 5999
# Files loaded: 1144 / 5999
# Files loaded: 1145 / 5999
# Files loaded: 1146 / 5999
# Files loaded: 1147 / 5999
# Files loaded: 1148 / 5999
# Files loaded: 1149 / 5999
# Files loaded: 1150 / 5999
# Files loaded: 1151 / 5999
# Files loaded: 1152 / 5999
# Files loaded: 1153 / 5999
# Files loaded: 1154 / 5999
# Files loaded: 1155 / 5999
# Files loaded: 1156 / 5999
# Files loaded: 1157 / 5999
# Files loaded: 1158 / 5999
# Files loaded: 1159 / 5999
# Files loaded: 1160 / 5999
# Files loaded: 1161 / 5999
# Files loaded: 1162 / 5999
# Files loaded: 1163 / 5999
# Files loaded: 1164 / 5999
# Files loaded: 1165 / 5999
# Files loaded: 1166 / 5999
# Files loaded: 1167 / 5999
# Files loaded: 1168 / 5999
# Files loaded: 1169 / 5999
# Files loaded: 1170 / 5999
# Files loaded: 1171 / 5999
# Files loaded: 1172 / 5999
# Files loaded: 1173 / 5999
# Files loaded: 1174 / 5999
# Files loaded: 1175 / 5999
# Files loaded: 1176 / 5999
# Files loaded: 1177 / 5999
# Files loaded: 1178 / 5999
# Files loaded: 1179 / 5999
# Files loaded: 1180 / 5999
# Files loaded: 1181 / 5999
# Files loaded: 1182 / 5999
# Files loaded: 1183 / 5999
# Files loaded: 1184 / 5999
# Files loaded: 1185 / 5999
# Files loaded: 1186 / 5999
# Files loaded: 1187 / 5999
# Files loaded: 1188 / 5999
# Files loaded: 1189 / 5999
# Files loaded: 1190 / 5999
# Files loaded: 1191 / 5999
# Files loaded: 1192 / 5999
# Files loaded: 1193 / 5999
# Files loaded: 1194 / 5999
# Files loaded: 1195 / 5999
# Files loaded: 1196 / 5999
# Files loaded: 1197 / 5999
# Files loaded: 1198 / 5999
# Files loaded: 1199 / 5999
# Files loaded: 1200 / 5999
# Files loaded: 1201 / 5999
# Files loaded: 1202 / 5999
# Files loaded: 1203 / 5999
# Files loaded: 1204 / 5999
# Files loaded: 1205 / 5999
# Files loaded: 1206 / 5999
# Files loaded: 1207 / 5999
# Files loaded: 1208 / 5999
# Files loaded: 1209 / 5999
# Files loaded: 1210 / 5999
# Files loaded: 1211 / 5999
# Files loaded: 1212 / 5999
# Files loaded: 1213 / 5999
# Files loaded: 1214 / 5999
# Files loaded: 1215 / 5999
# Files loaded: 1216 / 5999
# Files loaded: 1217 / 5999
# Files loaded: 1218 / 5999
# Files loaded: 1219 / 5999
# Files loaded: 1220 / 5999
# Files loaded: 1221 / 5999
# Files loaded: 1222 / 5999
# Files loaded: 1223 / 5999
# Files loaded: 1224 / 5999
# Files loaded: 1225 / 5999
# Files loaded: 1226 / 5999
# Files loaded: 1227 / 5999
# Files loaded: 1228 / 5999
# Files loaded: 1229 / 5999
# Files loaded: 1230 / 5999
# Files loaded: 1231 / 5999
# Files loaded: 1232 / 5999
# Files loaded: 1233 / 5999
# Files loaded: 1234 / 5999
# Files loaded: 1235 / 5999
# Files loaded: 1236 / 5999
# Files loaded: 1237 / 5999
# Files loaded: 1238 / 5999
# Files loaded: 1239 / 5999
# Files loaded: 1240 / 5999
# Files loaded: 1241 / 5999
# Files loaded: 1242 / 5999
# Files loaded: 1243 / 5999
# Files loaded: 1244 / 5999
# Files loaded: 1245 / 5999
# Files loaded: 1246 / 5999
# Files loaded: 1247 / 5999
# Files loaded: 1248 / 5999
# Files loaded: 1249 / 5999
# Files loaded: 1250 / 5999
# Files loaded: 1251 / 5999
# Files loaded: 1252 / 5999
# Files loaded: 1253 / 5999
# Files loaded: 1254 / 5999
# Files loaded: 1255 / 5999
# Files loaded: 1256 / 5999
# Files loaded: 1257 / 5999
# Files loaded: 1258 / 5999
# Files loaded: 1259 / 5999
# Files loaded: 1260 / 5999
# Files loaded: 1261 / 5999
# Files loaded: 1262 / 5999
# Files loaded: 1263 / 5999
# Files loaded: 1264 / 5999
# Files loaded: 1265 / 5999
# Files loaded: 1266 / 5999
# Files loaded: 1267 / 5999
# Files loaded: 1268 / 5999
# Files loaded: 1269 / 5999
# Files loaded: 1270 / 5999
# Files loaded: 1271 / 5999
# Files loaded: 1272 / 5999
# Files loaded: 1273 / 5999
# Files loaded: 1274 / 5999
# Files loaded: 1275 / 5999
# Files loaded: 1276 / 5999
# Files loaded: 1277 / 5999
# Files loaded: 1278 / 5999
# Files loaded: 1279 / 5999
# Files loaded: 1280 / 5999
# Files loaded: 1281 / 5999
# Files loaded: 1282 / 5999
# Files loaded: 1283 / 5999
# Files loaded: 1284 / 5999
# Files loaded: 1285 / 5999
# Files loaded: 1286 / 5999
# Files loaded: 1287 / 5999
# Files loaded: 1288 / 5999
# Files loaded: 1289 / 5999
# Files loaded: 1290 / 5999
# Files loaded: 1291 / 5999
# Files loaded: 1292 / 5999
# Files loaded: 1293 / 5999
# Files loaded: 1294 / 5999
# Files loaded: 1295 / 5999
# Files loaded: 1296 / 5999
# Files loaded: 1297 / 5999
# Files loaded: 1298 / 5999
# Files loaded: 1299 / 5999
# Files loaded: 1300 / 5999
# Files loaded: 1301 / 5999
# Files loaded: 1302 / 5999
# Files loaded: 1303 / 5999
# Files loaded: 1304 / 5999
# Files loaded: 1305 / 5999
# Files loaded: 1306 / 5999
# Files loaded: 1307 / 5999
# Files loaded: 1308 / 5999
# Files loaded: 1309 / 5999
# Files loaded: 1310 / 5999
# Files loaded: 1311 / 5999
# Files loaded: 1312 / 5999
# Files loaded: 1313 / 5999
# Files loaded: 1314 / 5999
# Files loaded: 1315 / 5999
# Files loaded: 1316 / 5999
# Files loaded: 1317 / 5999
# Files loaded: 1318 / 5999
# Files loaded: 1319 / 5999
# Files loaded: 1320 / 5999
# Files loaded: 1321 / 5999
# Files loaded: 1322 / 5999
# Files loaded: 1323 / 5999
# Files loaded: 1324 / 5999
# Files loaded: 1325 / 5999
# Files loaded: 1326 / 5999
# Files loaded: 1327 / 5999
# Files loaded: 1328 / 5999
# Files loaded: 1329 / 5999
# Files loaded: 1330 / 5999
# Files loaded: 1331 / 5999
# Files loaded: 1332 / 5999
# Files loaded: 1333 / 5999
# Files loaded: 1334 / 5999
# Files loaded: 1335 / 5999
# Files loaded: 1336 / 5999
# Files loaded: 1337 / 5999
# Files loaded: 1338 / 5999
# Files loaded: 1339 / 5999
# Files loaded: 1340 / 5999
# Files loaded: 1341 / 5999
# Files loaded: 1342 / 5999
# Files loaded: 1343 / 5999
# Files loaded: 1344 / 5999
# Files loaded: 1345 / 5999
# Files loaded: 1346 / 5999
# Files loaded: 1347 / 5999
# Files loaded: 1348 / 5999
# Files loaded: 1349 / 5999
# Files loaded: 1350 / 5999
# Files loaded: 1351 / 5999
# Files loaded: 1352 / 5999
# Files loaded: 1353 / 5999
# Files loaded: 1354 / 5999
# Files loaded: 1355 / 5999
# Files loaded: 1356 / 5999
# Files loaded: 1357 / 5999
# Files loaded: 1358 / 5999
# Files loaded: 1359 / 5999
# Files loaded: 1360 / 5999
# Files loaded: 1361 / 5999
# Files loaded: 1362 / 5999
# Files loaded: 1363 / 5999
# Files loaded: 1364 / 5999
# Files loaded: 1365 / 5999
# Files loaded: 1366 / 5999
# Files loaded: 1367 / 5999
# Files loaded: 1368 / 5999
# Files loaded: 1369 / 5999
# Files loaded: 1370 / 5999
# Files loaded: 1371 / 5999
# Files loaded: 1372 / 5999
# Files loaded: 1373 / 5999
# Files loaded: 1374 / 5999
# Files loaded: 1375 / 5999
# Files loaded: 1376 / 5999
# Files loaded: 1377 / 5999
# Files loaded: 1378 / 5999
# Files loaded: 1379 / 5999
# Files loaded: 1380 / 5999
# Files loaded: 1381 / 5999
# Files loaded: 1382 / 5999
# Files loaded: 1383 / 5999
# Files loaded: 1384 / 5999
# Files loaded: 1385 / 5999
# Files loaded: 1386 / 5999
# Files loaded: 1387 / 5999
# Files loaded: 1388 / 5999
# Files loaded: 1389 / 5999
# Files loaded: 1390 / 5999
# Files loaded: 1391 / 5999
# Files loaded: 1392 / 5999
# Files loaded: 1393 / 5999
# Files loaded: 1394 / 5999
# Files loaded: 1395 / 5999
# Files loaded: 1396 / 5999
# Files loaded: 1397 / 5999
# Files loaded: 1398 / 5999
# Files loaded: 1399 / 5999
# Files loaded: 1400 / 5999
# Files loaded: 1401 / 5999
# Files loaded: 1402 / 5999
# Files loaded: 1403 / 5999
# Files loaded: 1404 / 5999
# Files loaded: 1405 / 5999
# Files loaded: 1406 / 5999
# Files loaded: 1407 / 5999
# Files loaded: 1408 / 5999
# Files loaded: 1409 / 5999
# Files loaded: 1410 / 5999
# Files loaded: 1411 / 5999
# Files loaded: 1412 / 5999
# Files loaded: 1413 / 5999
# Files loaded: 1414 / 5999
# Files loaded: 1415 / 5999
# Files loaded: 1416 / 5999
# Files loaded: 1417 / 5999
# Files loaded: 1418 / 5999
# Files loaded: 1419 / 5999
# Files loaded: 1420 / 5999
# Files loaded: 1421 / 5999
# Files loaded: 1422 / 5999
# Files loaded: 1423 / 5999
# Files loaded: 1424 / 5999
# Files loaded: 1425 / 5999
# Files loaded: 1426 / 5999
# Files loaded: 1427 / 5999
# Files loaded: 1428 / 5999
# Files loaded: 1429 / 5999
# Files loaded: 1430 / 5999
# Files loaded: 1431 / 5999
# Files loaded: 1432 / 5999
# Files loaded: 1433 / 5999
# Files loaded: 1434 / 5999
# Files loaded: 1435 / 5999
# Files loaded: 1436 / 5999
# Files loaded: 1437 / 5999
# Files loaded: 1438 / 5999
# Files loaded: 1439 / 5999
# Files loaded: 1440 / 5999
# Files loaded: 1441 / 5999
# Files loaded: 1442 / 5999
# Files loaded: 1443 / 5999
# Files loaded: 1444 / 5999
# Files loaded: 1445 / 5999
# Files loaded: 1446 / 5999
# Files loaded: 1447 / 5999
# Files loaded: 1448 / 5999
# Files loaded: 1449 / 5999
# Files loaded: 1450 / 5999
# Files loaded: 1451 / 5999
# Files loaded: 1452 / 5999
# Files loaded: 1453 / 5999
# Files loaded: 1454 / 5999
# Files loaded: 1455 / 5999
# Files loaded: 1456 / 5999
# Files loaded: 1457 / 5999
# Files loaded: 1458 / 5999
# Files loaded: 1459 / 5999
# Files loaded: 1460 / 5999
# Files loaded: 1461 / 5999
# Files loaded: 1462 / 5999
# Files loaded: 1463 / 5999
# Files loaded: 1464 / 5999
# Files loaded: 1465 / 5999
# Files loaded: 1466 / 5999
# Files loaded: 1467 / 5999
# Files loaded: 1468 / 5999
# Files loaded: 1469 / 5999
# Files loaded: 1470 / 5999
# Files loaded: 1471 / 5999
# Files loaded: 1472 / 5999
# Files loaded: 1473 / 5999
# Files loaded: 1474 / 5999
# Files loaded: 1475 / 5999
# Files loaded: 1476 / 5999
# Files loaded: 1477 / 5999
# Files loaded: 1478 / 5999
# Files loaded: 1479 / 5999
# Files loaded: 1480 / 5999
# Files loaded: 1481 / 5999
# Files loaded: 1482 / 5999
# Files loaded: 1483 / 5999
# Files loaded: 1484 / 5999
# Files loaded: 1485 / 5999
# Files loaded: 1486 / 5999
# Files loaded: 1487 / 5999
# Files loaded: 1488 / 5999
# Files loaded: 1489 / 5999
# Files loaded: 1490 / 5999
# Files loaded: 1491 / 5999
# Files loaded: 1492 / 5999
# Files loaded: 1493 / 5999
# Files loaded: 1494 / 5999
# Files loaded: 1495 / 5999
# Files loaded: 1496 / 5999
# Files loaded: 1497 / 5999
# Files loaded: 1498 / 5999
# Files loaded: 1499 / 5999
# Files loaded: 1500 / 5999
# Files loaded: 1501 / 5999
# Files loaded: 1502 / 5999
# Files loaded: 1503 / 5999
# Files loaded: 1504 / 5999
# Files loaded: 1505 / 5999
# Files loaded: 1506 / 5999
# Files loaded: 1507 / 5999
# Files loaded: 1508 / 5999
# Files loaded: 1509 / 5999
# Files loaded: 1510 / 5999
# Files loaded: 1511 / 5999
# Files loaded: 1512 / 5999
# Files loaded: 1513 / 5999
# Files loaded: 1514 / 5999
# Files loaded: 1515 / 5999
# Files loaded: 1516 / 5999
# Files loaded: 1517 / 5999
# Files loaded: 1518 / 5999
# Files loaded: 1519 / 5999
# Files loaded: 1520 / 5999
# Files loaded: 1521 / 5999
# Files loaded: 1522 / 5999
# Files loaded: 1523 / 5999
# Files loaded: 1524 / 5999
# Files loaded: 1525 / 5999
# Files loaded: 1526 / 5999
# Files loaded: 1527 / 5999
# Files loaded: 1528 / 5999
# Files loaded: 1529 / 5999
# Files loaded: 1530 / 5999
# Files loaded: 1531 / 5999
# Files loaded: 1532 / 5999
# Files loaded: 1533 / 5999
# Files loaded: 1534 / 5999
# Files loaded: 1535 / 5999
# Files loaded: 1536 / 5999
# Files loaded: 1537 / 5999
# Files loaded: 1538 / 5999
# Files loaded: 1539 / 5999
# Files loaded: 1540 / 5999
# Files loaded: 1541 / 5999
# Files loaded: 1542 / 5999
# Files loaded: 1543 / 5999
# Files loaded: 1544 / 5999
# Files loaded: 1545 / 5999
# Files loaded: 1546 / 5999
# Files loaded: 1547 / 5999
# Files loaded: 1548 / 5999
# Files loaded: 1549 / 5999
# Files loaded: 1550 / 5999
# Files loaded: 1551 / 5999
# Files loaded: 1552 / 5999
# Files loaded: 1553 / 5999
# Files loaded: 1554 / 5999
# Files loaded: 1555 / 5999
# Files loaded: 1556 / 5999
# Files loaded: 1557 / 5999
# Files loaded: 1558 / 5999
# Files loaded: 1559 / 5999
# Files loaded: 1560 / 5999
# Files loaded: 1561 / 5999
# Files loaded: 1562 / 5999
# Files loaded: 1563 / 5999
# Files loaded: 1564 / 5999
# Files loaded: 1565 / 5999
# Files loaded: 1566 / 5999
# Files loaded: 1567 / 5999
# Files loaded: 1568 / 5999
# Files loaded: 1569 / 5999
# Files loaded: 1570 / 5999
# Files loaded: 1571 / 5999
# Files loaded: 1572 / 5999
# Files loaded: 1573 / 5999
# Files loaded: 1574 / 5999
# Files loaded: 1575 / 5999
# Files loaded: 1576 / 5999
# Files loaded: 1577 / 5999
# Files loaded: 1578 / 5999
# Files loaded: 1579 / 5999
# Files loaded: 1580 / 5999
# Files loaded: 1581 / 5999
# Files loaded: 1582 / 5999
# Files loaded: 1583 / 5999
# Files loaded: 1584 / 5999
# Files loaded: 1585 / 5999
# Files loaded: 1586 / 5999
# Files loaded: 1587 / 5999
# Files loaded: 1588 / 5999
# Files loaded: 1589 / 5999
# Files loaded: 1590 / 5999
# Files loaded: 1591 / 5999
# Files loaded: 1592 / 5999
# Files loaded: 1593 / 5999
# Files loaded: 1594 / 5999
# Files loaded: 1595 / 5999
# Files loaded: 1596 / 5999
# Files loaded: 1597 / 5999
# Files loaded: 1598 / 5999
# Files loaded: 1599 / 5999
# Files loaded: 1600 / 5999
# Files loaded: 1601 / 5999
# Files loaded: 1602 / 5999
# Files loaded: 1603 / 5999
# Files loaded: 1604 / 5999
# Files loaded: 1605 / 5999
# Files loaded: 1606 / 5999
# Files loaded: 1607 / 5999
# Files loaded: 1608 / 5999
# Files loaded: 1609 / 5999
# Files loaded: 1610 / 5999
# Files loaded: 1611 / 5999
# Files loaded: 1612 / 5999
# Files loaded: 1613 / 5999
# Files loaded: 1614 / 5999
# Files loaded: 1615 / 5999
# Files loaded: 1616 / 5999
# Files loaded: 1617 / 5999
# Files loaded: 1618 / 5999
# Files loaded: 1619 / 5999
# Files loaded: 1620 / 5999
# Files loaded: 1621 / 5999
# Files loaded: 1622 / 5999
# Files loaded: 1623 / 5999
# Files loaded: 1624 / 5999
# Files loaded: 1625 / 5999
# Files loaded: 1626 / 5999
# Files loaded: 1627 / 5999
# Files loaded: 1628 / 5999
# Files loaded: 1629 / 5999
# Files loaded: 1630 / 5999
# Files loaded: 1631 / 5999
# Files loaded: 1632 / 5999
# Files loaded: 1633 / 5999
# Files loaded: 1634 / 5999
# Files loaded: 1635 / 5999
# Files loaded: 1636 / 5999
# Files loaded: 1637 / 5999
# Files loaded: 1638 / 5999
# Files loaded: 1639 / 5999
# Files loaded: 1640 / 5999
# Files loaded: 1641 / 5999
# Files loaded: 1642 / 5999
# Files loaded: 1643 / 5999
# Files loaded: 1644 / 5999
# Files loaded: 1645 / 5999
# Files loaded: 1646 / 5999
# Files loaded: 1647 / 5999
# Files loaded: 1648 / 5999
# Files loaded: 1649 / 5999
# Files loaded: 1650 / 5999
# Files loaded: 1651 / 5999
# Files loaded: 1652 / 5999
# Files loaded: 1653 / 5999
# Files loaded: 1654 / 5999
# Files loaded: 1655 / 5999
# Files loaded: 1656 / 5999
# Files loaded: 1657 / 5999
# Files loaded: 1658 / 5999
# Files loaded: 1659 / 5999
# Files loaded: 1660 / 5999
# Files loaded: 1661 / 5999
# Files loaded: 1662 / 5999
# Files loaded: 1663 / 5999
# Files loaded: 1664 / 5999
# Files loaded: 1665 / 5999
# Files loaded: 1666 / 5999
# Files loaded: 1667 / 5999
# Files loaded: 1668 / 5999
# Files loaded: 1669 / 5999
# Files loaded: 1670 / 5999
# Files loaded: 1671 / 5999
# Files loaded: 1672 / 5999
# Files loaded: 1673 / 5999
# Files loaded: 1674 / 5999
# Files loaded: 1675 / 5999
# Files loaded: 1676 / 5999
# Files loaded: 1677 / 5999
# Files loaded: 1678 / 5999
# Files loaded: 1679 / 5999
# Files loaded: 1680 / 5999
# Files loaded: 1681 / 5999
# Files loaded: 1682 / 5999
# Files loaded: 1683 / 5999
# Files loaded: 1684 / 5999
# Files loaded: 1685 / 5999
# Files loaded: 1686 / 5999
# Files loaded: 1687 / 5999
# Files loaded: 1688 / 5999
# Files loaded: 1689 / 5999
# Files loaded: 1690 / 5999
# Files loaded: 1691 / 5999
# Files loaded: 1692 / 5999
# Files loaded: 1693 / 5999
# Files loaded: 1694 / 5999
# Files loaded: 1695 / 5999
# Files loaded: 1696 / 5999
# Files loaded: 1697 / 5999
# Files loaded: 1698 / 5999
# Files loaded: 1699 / 5999
# Files loaded: 1700 / 5999
# Files loaded: 1701 / 5999
# Files loaded: 1702 / 5999
# Files loaded: 1703 / 5999
# Files loaded: 1704 / 5999
# Files loaded: 1705 / 5999
# Files loaded: 1706 / 5999
# Files loaded: 1707 / 5999
# Files loaded: 1708 / 5999
# Files loaded: 1709 / 5999
# Files loaded: 1710 / 5999
# Files loaded: 1711 / 5999
# Files loaded: 1712 / 5999
# Files loaded: 1713 / 5999
# Files loaded: 1714 / 5999
# Files loaded: 1715 / 5999
# Files loaded: 1716 / 5999
# Files loaded: 1717 / 5999
# Files loaded: 1718 / 5999
# Files loaded: 1719 / 5999
# Files loaded: 1720 / 5999
# Files loaded: 1721 / 5999
# Files loaded: 1722 / 5999
# Files loaded: 1723 / 5999
# Files loaded: 1724 / 5999
# Files loaded: 1725 / 5999
# Files loaded: 1726 / 5999
# Files loaded: 1727 / 5999
# Files loaded: 1728 / 5999
# Files loaded: 1729 / 5999
# Files loaded: 1730 / 5999
# Files loaded: 1731 / 5999
# Files loaded: 1732 / 5999
# Files loaded: 1733 / 5999
# Files loaded: 1734 / 5999
# Files loaded: 1735 / 5999
# Files loaded: 1736 / 5999
# Files loaded: 1737 / 5999
# Files loaded: 1738 / 5999
# Files loaded: 1739 / 5999
# Files loaded: 1740 / 5999
# Files loaded: 1741 / 5999
# Files loaded: 1742 / 5999
# Files loaded: 1743 / 5999
# Files loaded: 1744 / 5999
# Files loaded: 1745 / 5999
# Files loaded: 1746 / 5999
# Files loaded: 1747 / 5999
# Files loaded: 1748 / 5999
# Files loaded: 1749 / 5999
# Files loaded: 1750 / 5999
# Files loaded: 1751 / 5999
# Files loaded: 1752 / 5999
# Files loaded: 1753 / 5999
# Files loaded: 1754 / 5999
# Files loaded: 1755 / 5999
# Files loaded: 1756 / 5999
# Files loaded: 1757 / 5999
# Files loaded: 1758 / 5999
# Files loaded: 1759 / 5999
# Files loaded: 1760 / 5999
# Files loaded: 1761 / 5999
# Files loaded: 1762 / 5999
# Files loaded: 1763 / 5999
# Files loaded: 1764 / 5999
# Files loaded: 1765 / 5999
# Files loaded: 1766 / 5999
# Files loaded: 1767 / 5999
# Files loaded: 1768 / 5999
# Files loaded: 1769 / 5999
# Files loaded: 1770 / 5999
# Files loaded: 1771 / 5999
# Files loaded: 1772 / 5999
# Files loaded: 1773 / 5999
# Files loaded: 1774 / 5999
# Files loaded: 1775 / 5999
# Files loaded: 1776 / 5999
# Files loaded: 1777 / 5999
# Files loaded: 1778 / 5999
# Files loaded: 1779 / 5999
# Files loaded: 1780 / 5999
# Files loaded: 1781 / 5999
# Files loaded: 1782 / 5999
# Files loaded: 1783 / 5999
# Files loaded: 1784 / 5999
# Files loaded: 1785 / 5999
# Files loaded: 1786 / 5999
# Files loaded: 1787 / 5999
# Files loaded: 1788 / 5999
# Files loaded: 1789 / 5999
# Files loaded: 1790 / 5999
# Files loaded: 1791 / 5999
# Files loaded: 1792 / 5999
# Files loaded: 1793 / 5999
# Files loaded: 1794 / 5999
# Files loaded: 1795 / 5999
# Files loaded: 1796 / 5999
# Files loaded: 1797 / 5999
# Files loaded: 1798 / 5999
# Files loaded: 1799 / 5999
# Files loaded: 1800 / 5999
# Files loaded: 1801 / 5999
# Files loaded: 1802 / 5999
# Files loaded: 1803 / 5999
# Files loaded: 1804 / 5999
# Files loaded: 1805 / 5999
# Files loaded: 1806 / 5999
# Files loaded: 1807 / 5999
# Files loaded: 1808 / 5999
# Files loaded: 1809 / 5999
# Files loaded: 1810 / 5999
# Files loaded: 1811 / 5999
# Files loaded: 1812 / 5999
# Files loaded: 1813 / 5999
# Files loaded: 1814 / 5999
# Files loaded: 1815 / 5999
# Files loaded: 1816 / 5999
# Files loaded: 1817 / 5999
# Files loaded: 1818 / 5999
# Files loaded: 1819 / 5999
# Files loaded: 1820 / 5999
# Files loaded: 1821 / 5999
# Files loaded: 1822 / 5999
# Files loaded: 1823 / 5999
# Files loaded: 1824 / 5999
# Files loaded: 1825 / 5999
# Files loaded: 1826 / 5999
# Files loaded: 1827 / 5999
# Files loaded: 1828 / 5999
# Files loaded: 1829 / 5999
# Files loaded: 1830 / 5999
# Files loaded: 1831 / 5999
# Files loaded: 1832 / 5999
# Files loaded: 1833 / 5999
# Files loaded: 1834 / 5999
# Files loaded: 1835 / 5999
# Files loaded: 1836 / 5999
# Files loaded: 1837 / 5999
# Files loaded: 1838 / 5999
# Files loaded: 1839 / 5999
# Files loaded: 1840 / 5999
# Files loaded: 1841 / 5999
# Files loaded: 1842 / 5999
# Files loaded: 1843 / 5999
# Files loaded: 1844 / 5999
# Files loaded: 1845 / 5999
# Files loaded: 1846 / 5999
# Files loaded: 1847 / 5999
# Files loaded: 1848 / 5999
# Files loaded: 1849 / 5999
# Files loaded: 1850 / 5999
# Files loaded: 1851 / 5999
# Files loaded: 1852 / 5999
# Files loaded: 1853 / 5999
# Files loaded: 1854 / 5999
# Files loaded: 1855 / 5999
# Files loaded: 1856 / 5999
# Files loaded: 1857 / 5999
# Files loaded: 1858 / 5999
# Files loaded: 1859 / 5999
# Files loaded: 1860 / 5999
# Files loaded: 1861 / 5999
# Files loaded: 1862 / 5999
# Files loaded: 1863 / 5999
# Files loaded: 1864 / 5999
# Files loaded: 1865 / 5999
# Files loaded: 1866 / 5999
# Files loaded: 1867 / 5999
# Files loaded: 1868 / 5999
# Files loaded: 1869 / 5999
# Files loaded: 1870 / 5999
# Files loaded: 1871 / 5999
# Files loaded: 1872 / 5999
# Files loaded: 1873 / 5999
# Files loaded: 1874 / 5999
# Files loaded: 1875 / 5999
# Files loaded: 1876 / 5999
# Files loaded: 1877 / 5999
# Files loaded: 1878 / 5999
# Files loaded: 1879 / 5999
# Files loaded: 1880 / 5999
# Files loaded: 1881 / 5999
# Files loaded: 1882 / 5999
# Files loaded: 1883 / 5999
# Files loaded: 1884 / 5999
# Files loaded: 1885 / 5999
# Files loaded: 1886 / 5999
# Files loaded: 1887 / 5999
# Files loaded: 1888 / 5999
# Files loaded: 1889 / 5999
# Files loaded: 1890 / 5999
# Files loaded: 1891 / 5999
# Files loaded: 1892 / 5999
# Files loaded: 1893 / 5999
# Files loaded: 1894 / 5999
# Files loaded: 1895 / 5999
# Files loaded: 1896 / 5999
# Files loaded: 1897 / 5999
# Files loaded: 1898 / 5999
# Files loaded: 1899 / 5999
# Files loaded: 1900 / 5999
# Files loaded: 1901 / 5999
# Files loaded: 1902 / 5999
# Files loaded: 1903 / 5999
# Files loaded: 1904 / 5999
# Files loaded: 1905 / 5999
# Files loaded: 1906 / 5999
# Files loaded: 1907 / 5999
# Files loaded: 1908 / 5999
# Files loaded: 1909 / 5999
# Files loaded: 1910 / 5999
# Files loaded: 1911 / 5999
# Files loaded: 1912 / 5999
# Files loaded: 1913 / 5999
# Files loaded: 1914 / 5999
# Files loaded: 1915 / 5999
# Files loaded: 1916 / 5999
# Files loaded: 1917 / 5999
# Files loaded: 1918 / 5999
# Files loaded: 1919 / 5999
# Files loaded: 1920 / 5999
# Files loaded: 1921 / 5999
# Files loaded: 1922 / 5999
# Files loaded: 1923 / 5999
# Files loaded: 1924 / 5999
# Files loaded: 1925 / 5999
# Files loaded: 1926 / 5999
# Files loaded: 1927 / 5999
# Files loaded: 1928 / 5999
# Files loaded: 1929 / 5999
# Files loaded: 1930 / 5999
# Files loaded: 1931 / 5999
# Files loaded: 1932 / 5999
# Files loaded: 1933 / 5999
# Files loaded: 1934 / 5999
# Files loaded: 1935 / 5999
# Files loaded: 1936 / 5999
# Files loaded: 1937 / 5999
# Files loaded: 1938 / 5999
# Files loaded: 1939 / 5999
# Files loaded: 1940 / 5999
# Files loaded: 1941 / 5999
# Files loaded: 1942 / 5999
# Files loaded: 1943 / 5999
# Files loaded: 1944 / 5999
# Files loaded: 1945 / 5999
# Files loaded: 1946 / 5999
# Files loaded: 1947 / 5999
# Files loaded: 1948 / 5999
# Files loaded: 1949 / 5999
# Files loaded: 1950 / 5999
# Files loaded: 1951 / 5999
# Files loaded: 1952 / 5999
# Files loaded: 1953 / 5999
# Files loaded: 1954 / 5999
# Files loaded: 1955 / 5999
# Files loaded: 1956 / 5999
# Files loaded: 1957 / 5999
# Files loaded: 1958 / 5999
# Files loaded: 1959 / 5999
# Files loaded: 1960 / 5999
# Files loaded: 1961 / 5999
# Files loaded: 1962 / 5999
# Files loaded: 1963 / 5999
# Files loaded: 1964 / 5999
# Files loaded: 1965 / 5999
# Files loaded: 1966 / 5999
# Files loaded: 1967 / 5999
# Files loaded: 1968 / 5999
# Files loaded: 1969 / 5999
# Files loaded: 1970 / 5999
# Files loaded: 1971 / 5999
# Files loaded: 1972 / 5999
# Files loaded: 1973 / 5999
# Files loaded: 1974 / 5999
# Files loaded: 1975 / 5999
# Files loaded: 1976 / 5999
# Files loaded: 1977 / 5999
# Files loaded: 1978 / 5999
# Files loaded: 1979 / 5999
# Files loaded: 1980 / 5999
# Files loaded: 1981 / 5999
# Files loaded: 1982 / 5999
# Files loaded: 1983 / 5999
# Files loaded: 1984 / 5999
# Files loaded: 1985 / 5999
# Files loaded: 1986 / 5999
# Files loaded: 1987 / 5999
# Files loaded: 1988 / 5999
# Files loaded: 1989 / 5999
# Files loaded: 1990 / 5999
# Files loaded: 1991 / 5999
# Files loaded: 1992 / 5999
# Files loaded: 1993 / 5999
# Files loaded: 1994 / 5999
# Files loaded: 1995 / 5999
# Files loaded: 1996 / 5999
# Files loaded: 1997 / 5999
# Files loaded: 1998 / 5999
# Files loaded: 1999 / 5999
# Files loaded: 2000 / 5999
# Loading files for class: atrial_preprocessed
# Total files available: 38642
# Target files to load: 2000
# Files loaded: 2001 / 5999
# Files loaded: 2002 / 5999
# Files loaded: 2003 / 5999
# Files loaded: 2004 / 5999
# Files loaded: 2005 / 5999
# Files loaded: 2006 / 5999
# Files loaded: 2007 / 5999
# Files loaded: 2008 / 5999
# Files loaded: 2009 / 5999
# Files loaded: 2010 / 5999
# Files loaded: 2011 / 5999
# Files loaded: 2012 / 5999
# Files loaded: 2013 / 5999
# Files loaded: 2014 / 5999
# Files loaded: 2015 / 5999
# Files loaded: 2016 / 5999
# Files loaded: 2017 / 5999
# Files loaded: 2018 / 5999
# Files loaded: 2019 / 5999
# Files loaded: 2020 / 5999
# Files loaded: 2021 / 5999
# Files loaded: 2022 / 5999
# Files loaded: 2023 / 5999
# Files loaded: 2024 / 5999
# Files loaded: 2025 / 5999
# Files loaded: 2026 / 5999
# Files loaded: 2027 / 5999
# Files loaded: 2028 / 5999
# Files loaded: 2029 / 5999
# Files loaded: 2030 / 5999
# Files loaded: 2031 / 5999
# Files loaded: 2032 / 5999
# Files loaded: 2033 / 5999
# Files loaded: 2034 / 5999
# Files loaded: 2035 / 5999
# Files loaded: 2036 / 5999
# Files loaded: 2037 / 5999
# Files loaded: 2038 / 5999
# Files loaded: 2039 / 5999
# Files loaded: 2040 / 5999
# Files loaded: 2041 / 5999
# Files loaded: 2042 / 5999
# Files loaded: 2043 / 5999
# Files loaded: 2044 / 5999
# Files loaded: 2045 / 5999
# Files loaded: 2046 / 5999
# Files loaded: 2047 / 5999
# Files loaded: 2048 / 5999
# Files loaded: 2049 / 5999
# Files loaded: 2050 / 5999
# Files loaded: 2051 / 5999
# Files loaded: 2052 / 5999
# Files loaded: 2053 / 5999
# Files loaded: 2054 / 5999
# Files loaded: 2055 / 5999
# Files loaded: 2056 / 5999
# Files loaded: 2057 / 5999
# Files loaded: 2058 / 5999
# Files loaded: 2059 / 5999
# Files loaded: 2060 / 5999
# Files loaded: 2061 / 5999
# Files loaded: 2062 / 5999
# Files loaded: 2063 / 5999
# Files loaded: 2064 / 5999
# Files loaded: 2065 / 5999
# Files loaded: 2066 / 5999
# Files loaded: 2067 / 5999
# Files loaded: 2068 / 5999
# Files loaded: 2069 / 5999
# Files loaded: 2070 / 5999
# Files loaded: 2071 / 5999
# Files loaded: 2072 / 5999
# Files loaded: 2073 / 5999
# Files loaded: 2074 / 5999
# Files loaded: 2075 / 5999
# Files loaded: 2076 / 5999
# Files loaded: 2077 / 5999
# Files loaded: 2078 / 5999
# Files loaded: 2079 / 5999
# Files loaded: 2080 / 5999
# Files loaded: 2081 / 5999
# Files loaded: 2082 / 5999
# Files loaded: 2083 / 5999
# Files loaded: 2084 / 5999
# Files loaded: 2085 / 5999
# Files loaded: 2086 / 5999
# Files loaded: 2087 / 5999
# Files loaded: 2088 / 5999
# Files loaded: 2089 / 5999
# Files loaded: 2090 / 5999
# Files loaded: 2091 / 5999
# Files loaded: 2092 / 5999
# Files loaded: 2093 / 5999
# Files loaded: 2094 / 5999
# Files loaded: 2095 / 5999
# Files loaded: 2096 / 5999
# Files loaded: 2097 / 5999
# Files loaded: 2098 / 5999
# Files loaded: 2099 / 5999
# Files loaded: 2100 / 5999
# Files loaded: 2101 / 5999
# Files loaded: 2102 / 5999
# Files loaded: 2103 / 5999
# Files loaded: 2104 / 5999
# Files loaded: 2105 / 5999
# Files loaded: 2106 / 5999
# Files loaded: 2107 / 5999
# Files loaded: 2108 / 5999
# Files loaded: 2109 / 5999
# Files loaded: 2110 / 5999
# Files loaded: 2111 / 5999
# Files loaded: 2112 / 5999
# Files loaded: 2113 / 5999
# Files loaded: 2114 / 5999
# Files loaded: 2115 / 5999
# Files loaded: 2116 / 5999
# Files loaded: 2117 / 5999
# Files loaded: 2118 / 5999
# Files loaded: 2119 / 5999
# Files loaded: 2120 / 5999
# Files loaded: 2121 / 5999
# Files loaded: 2122 / 5999
# Files loaded: 2123 / 5999
# Files loaded: 2124 / 5999
# Files loaded: 2125 / 5999
# Files loaded: 2126 / 5999
# Files loaded: 2127 / 5999
# Files loaded: 2128 / 5999
# Files loaded: 2129 / 5999
# Files loaded: 2130 / 5999
# Files loaded: 2131 / 5999
# Files loaded: 2132 / 5999
# Files loaded: 2133 / 5999
# Files loaded: 2134 / 5999
# Files loaded: 2135 / 5999
# Files loaded: 2136 / 5999
# Files loaded: 2137 / 5999
# Files loaded: 2138 / 5999
# Files loaded: 2139 / 5999
# Files loaded: 2140 / 5999
# Files loaded: 2141 / 5999
# Files loaded: 2142 / 5999
# Files loaded: 2143 / 5999
# Files loaded: 2144 / 5999
# Files loaded: 2145 / 5999
# Files loaded: 2146 / 5999
# Files loaded: 2147 / 5999
# Files loaded: 2148 / 5999
# Files loaded: 2149 / 5999
# Files loaded: 2150 / 5999
# Files loaded: 2151 / 5999
# Files loaded: 2152 / 5999
# Files loaded: 2153 / 5999
# Files loaded: 2154 / 5999
# Files loaded: 2155 / 5999
# Files loaded: 2156 / 5999
# Files loaded: 2157 / 5999
# Files loaded: 2158 / 5999
# Files loaded: 2159 / 5999
# Files loaded: 2160 / 5999
# Files loaded: 2161 / 5999
# Files loaded: 2162 / 5999
# Files loaded: 2163 / 5999
# Files loaded: 2164 / 5999
# Files loaded: 2165 / 5999
# Files loaded: 2166 / 5999
# Files loaded: 2167 / 5999
# Files loaded: 2168 / 5999
# Files loaded: 2169 / 5999
# Files loaded: 2170 / 5999
# Files loaded: 2171 / 5999
# Files loaded: 2172 / 5999
# Files loaded: 2173 / 5999
# Files loaded: 2174 / 5999
# Files loaded: 2175 / 5999
# Files loaded: 2176 / 5999
# Files loaded: 2177 / 5999
# Files loaded: 2178 / 5999
# Files loaded: 2179 / 5999
# Files loaded: 2180 / 5999
# Files loaded: 2181 / 5999
# Files loaded: 2182 / 5999
# Files loaded: 2183 / 5999
# Files loaded: 2184 / 5999
# Files loaded: 2185 / 5999
# Files loaded: 2186 / 5999
# Files loaded: 2187 / 5999
# Files loaded: 2188 / 5999
# Files loaded: 2189 / 5999
# Files loaded: 2190 / 5999
# Files loaded: 2191 / 5999
# Files loaded: 2192 / 5999
# Files loaded: 2193 / 5999
# Files loaded: 2194 / 5999
# Files loaded: 2195 / 5999
# Files loaded: 2196 / 5999
# Files loaded: 2197 / 5999
# Files loaded: 2198 / 5999
# Files loaded: 2199 / 5999
# Files loaded: 2200 / 5999
# Files loaded: 2201 / 5999
# Files loaded: 2202 / 5999
# Files loaded: 2203 / 5999
# Files loaded: 2204 / 5999
# Files loaded: 2205 / 5999
# Files loaded: 2206 / 5999
# Files loaded: 2207 / 5999
# Files loaded: 2208 / 5999
# Files loaded: 2209 / 5999
# Files loaded: 2210 / 5999
# Files loaded: 2211 / 5999
# Files loaded: 2212 / 5999
# Files loaded: 2213 / 5999
# Files loaded: 2214 / 5999
# Files loaded: 2215 / 5999
# Files loaded: 2216 / 5999
# Files loaded: 2217 / 5999
# Files loaded: 2218 / 5999
# Files loaded: 2219 / 5999
# Files loaded: 2220 / 5999
# Files loaded: 2221 / 5999
# Files loaded: 2222 / 5999
# Files loaded: 2223 / 5999
# Files loaded: 2224 / 5999
# Files loaded: 2225 / 5999
# Files loaded: 2226 / 5999
# Files loaded: 2227 / 5999
# Files loaded: 2228 / 5999
# Files loaded: 2229 / 5999
# Files loaded: 2230 / 5999
# Files loaded: 2231 / 5999
# Files loaded: 2232 / 5999
# Files loaded: 2233 / 5999
# Files loaded: 2234 / 5999
# Files loaded: 2235 / 5999
# Files loaded: 2236 / 5999
# Files loaded: 2237 / 5999
# Files loaded: 2238 / 5999
# Files loaded: 2239 / 5999
# Files loaded: 2240 / 5999
# Files loaded: 2241 / 5999
# Files loaded: 2242 / 5999
# Files loaded: 2243 / 5999
# Files loaded: 2244 / 5999
# Files loaded: 2245 / 5999
# Files loaded: 2246 / 5999
# Files loaded: 2247 / 5999
# Files loaded: 2248 / 5999
# Files loaded: 2249 / 5999
# Files loaded: 2250 / 5999
# Files loaded: 2251 / 5999
# Files loaded: 2252 / 5999
# Files loaded: 2253 / 5999
# Files loaded: 2254 / 5999
# Files loaded: 2255 / 5999
# Files loaded: 2256 / 5999
# Files loaded: 2257 / 5999
# Files loaded: 2258 / 5999
# Files loaded: 2259 / 5999
# Files loaded: 2260 / 5999
# Files loaded: 2261 / 5999
# Files loaded: 2262 / 5999
# Files loaded: 2263 / 5999
# Files loaded: 2264 / 5999
# Files loaded: 2265 / 5999
# Files loaded: 2266 / 5999
# Files loaded: 2267 / 5999
# Files loaded: 2268 / 5999
# Files loaded: 2269 / 5999
# Files loaded: 2270 / 5999
# Files loaded: 2271 / 5999
# Files loaded: 2272 / 5999
# Files loaded: 2273 / 5999
# Files loaded: 2274 / 5999
# Files loaded: 2275 / 5999
# Files loaded: 2276 / 5999
# Files loaded: 2277 / 5999
# Files loaded: 2278 / 5999
# Files loaded: 2279 / 5999
# Files loaded: 2280 / 5999
# Files loaded: 2281 / 5999
# Files loaded: 2282 / 5999
# Files loaded: 2283 / 5999
# Files loaded: 2284 / 5999
# Files loaded: 2285 / 5999
# Files loaded: 2286 / 5999
# Files loaded: 2287 / 5999
# Files loaded: 2288 / 5999
# Files loaded: 2289 / 5999
# Files loaded: 2290 / 5999
# Files loaded: 2291 / 5999
# Files loaded: 2292 / 5999
# Files loaded: 2293 / 5999
# Files loaded: 2294 / 5999
# Files loaded: 2295 / 5999
# Files loaded: 2296 / 5999
# Files loaded: 2297 / 5999
# Files loaded: 2298 / 5999
# Files loaded: 2299 / 5999
# Files loaded: 2300 / 5999
# Files loaded: 2301 / 5999
# Files loaded: 2302 / 5999
# Files loaded: 2303 / 5999
# Files loaded: 2304 / 5999
# Files loaded: 2305 / 5999
# Files loaded: 2306 / 5999
# Files loaded: 2307 / 5999
# Files loaded: 2308 / 5999
# Files loaded: 2309 / 5999
# Files loaded: 2310 / 5999
# Files loaded: 2311 / 5999
# Files loaded: 2312 / 5999
# Files loaded: 2313 / 5999
# Files loaded: 2314 / 5999
# Files loaded: 2315 / 5999
# Files loaded: 2316 / 5999
# Files loaded: 2317 / 5999
# Files loaded: 2318 / 5999
# Files loaded: 2319 / 5999
# Files loaded: 2320 / 5999
# Files loaded: 2321 / 5999
# Files loaded: 2322 / 5999
# Files loaded: 2323 / 5999
# Files loaded: 2324 / 5999
# Files loaded: 2325 / 5999
# Files loaded: 2326 / 5999
# Files loaded: 2327 / 5999
# Files loaded: 2328 / 5999
# Files loaded: 2329 / 5999
# Files loaded: 2330 / 5999
# Files loaded: 2331 / 5999
# Files loaded: 2332 / 5999
# Files loaded: 2333 / 5999
# Files loaded: 2334 / 5999
# Files loaded: 2335 / 5999
# Files loaded: 2336 / 5999
# Files loaded: 2337 / 5999
# Files loaded: 2338 / 5999
# Files loaded: 2339 / 5999
# Files loaded: 2340 / 5999
# Files loaded: 2341 / 5999
# Files loaded: 2342 / 5999
# Files loaded: 2343 / 5999
# Files loaded: 2344 / 5999
# Files loaded: 2345 / 5999
# Files loaded: 2346 / 5999
# Files loaded: 2347 / 5999
# Files loaded: 2348 / 5999
# Files loaded: 2349 / 5999
# Files loaded: 2350 / 5999
# Files loaded: 2351 / 5999
# Files loaded: 2352 / 5999
# Files loaded: 2353 / 5999
# Files loaded: 2354 / 5999
# Files loaded: 2355 / 5999
# Files loaded: 2356 / 5999
# Files loaded: 2357 / 5999
# Files loaded: 2358 / 5999
# Files loaded: 2359 / 5999
# Files loaded: 2360 / 5999
# Files loaded: 2361 / 5999
# Files loaded: 2362 / 5999
# Files loaded: 2363 / 5999
# Files loaded: 2364 / 5999
# Files loaded: 2365 / 5999
# Files loaded: 2366 / 5999
# Files loaded: 2367 / 5999
# Files loaded: 2368 / 5999
# Files loaded: 2369 / 5999
# Files loaded: 2370 / 5999
# Files loaded: 2371 / 5999
# Files loaded: 2372 / 5999
# Files loaded: 2373 / 5999
# Files loaded: 2374 / 5999
# Files loaded: 2375 / 5999
# Files loaded: 2376 / 5999
# Files loaded: 2377 / 5999
# Files loaded: 2378 / 5999
# Files loaded: 2379 / 5999
# Files loaded: 2380 / 5999
# Files loaded: 2381 / 5999
# Files loaded: 2382 / 5999
# Files loaded: 2383 / 5999
# Files loaded: 2384 / 5999
# Files loaded: 2385 / 5999
# Files loaded: 2386 / 5999
# Files loaded: 2387 / 5999
# Files loaded: 2388 / 5999
# Files loaded: 2389 / 5999
# Files loaded: 2390 / 5999
# Files loaded: 2391 / 5999
# Files loaded: 2392 / 5999
# Files loaded: 2393 / 5999
# Files loaded: 2394 / 5999
# Files loaded: 2395 / 5999
# Files loaded: 2396 / 5999
# Files loaded: 2397 / 5999
# Files loaded: 2398 / 5999
# Files loaded: 2399 / 5999
# Files loaded: 2400 / 5999
# Files loaded: 2401 / 5999
# Files loaded: 2402 / 5999
# Files loaded: 2403 / 5999
# Files loaded: 2404 / 5999
# Files loaded: 2405 / 5999
# Files loaded: 2406 / 5999
# Files loaded: 2407 / 5999
# Files loaded: 2408 / 5999
# Files loaded: 2409 / 5999
# Files loaded: 2410 / 5999
# Files loaded: 2411 / 5999
# Files loaded: 2412 / 5999
# Files loaded: 2413 / 5999
# Files loaded: 2414 / 5999
# Files loaded: 2415 / 5999
# Files loaded: 2416 / 5999
# Files loaded: 2417 / 5999
# Files loaded: 2418 / 5999
# Files loaded: 2419 / 5999
# Files loaded: 2420 / 5999
# Files loaded: 2421 / 5999
# Files loaded: 2422 / 5999
# Files loaded: 2423 / 5999
# Files loaded: 2424 / 5999
# Files loaded: 2425 / 5999
# Files loaded: 2426 / 5999
# Files loaded: 2427 / 5999
# Files loaded: 2428 / 5999
# Files loaded: 2429 / 5999
# Files loaded: 2430 / 5999
# Files loaded: 2431 / 5999
# Files loaded: 2432 / 5999
# Files loaded: 2433 / 5999
# Files loaded: 2434 / 5999
# Files loaded: 2435 / 5999
# Files loaded: 2436 / 5999
# Files loaded: 2437 / 5999
# Files loaded: 2438 / 5999
# Files loaded: 2439 / 5999
# Files loaded: 2440 / 5999
# Files loaded: 2441 / 5999
# Files loaded: 2442 / 5999
# Files loaded: 2443 / 5999
# Files loaded: 2444 / 5999
# Files loaded: 2445 / 5999
# Files loaded: 2446 / 5999
# Files loaded: 2447 / 5999
# Files loaded: 2448 / 5999
# Files loaded: 2449 / 5999
# Files loaded: 2450 / 5999
# Files loaded: 2451 / 5999
# Files loaded: 2452 / 5999
# Files loaded: 2453 / 5999
# Files loaded: 2454 / 5999
# Files loaded: 2455 / 5999
# Files loaded: 2456 / 5999
# Files loaded: 2457 / 5999
# Files loaded: 2458 / 5999
# Files loaded: 2459 / 5999
# Files loaded: 2460 / 5999
# Files loaded: 2461 / 5999
# Files loaded: 2462 / 5999
# Files loaded: 2463 / 5999
# Files loaded: 2464 / 5999
# Files loaded: 2465 / 5999
# Files loaded: 2466 / 5999
# Files loaded: 2467 / 5999
# Files loaded: 2468 / 5999
# Files loaded: 2469 / 5999
# Files loaded: 2470 / 5999
# Files loaded: 2471 / 5999
# Files loaded: 2472 / 5999
# Files loaded: 2473 / 5999
# Files loaded: 2474 / 5999
# Files loaded: 2475 / 5999
# Files loaded: 2476 / 5999
# Files loaded: 2477 / 5999
# Files loaded: 2478 / 5999
# Files loaded: 2479 / 5999
# Files loaded: 2480 / 5999
# Files loaded: 2481 / 5999
# Files loaded: 2482 / 5999
# Files loaded: 2483 / 5999
# Files loaded: 2484 / 5999
# Files loaded: 2485 / 5999
# Files loaded: 2486 / 5999
# Files loaded: 2487 / 5999
# Files loaded: 2488 / 5999
# Files loaded: 2489 / 5999
# Files loaded: 2490 / 5999
# Files loaded: 2491 / 5999
# Files loaded: 2492 / 5999
# Files loaded: 2493 / 5999
# Files loaded: 2494 / 5999
# Files loaded: 2495 / 5999
# Files loaded: 2496 / 5999
# Files loaded: 2497 / 5999
# Files loaded: 2498 / 5999
# Files loaded: 2499 / 5999
# Files loaded: 2500 / 5999
# Files loaded: 2501 / 5999
# Files loaded: 2502 / 5999
# Files loaded: 2503 / 5999
# Files loaded: 2504 / 5999
# Files loaded: 2505 / 5999
# Files loaded: 2506 / 5999
# Files loaded: 2507 / 5999
# Files loaded: 2508 / 5999
# Files loaded: 2509 / 5999
# Files loaded: 2510 / 5999
# Files loaded: 2511 / 5999
# Files loaded: 2512 / 5999
# Files loaded: 2513 / 5999
# Files loaded: 2514 / 5999
# Files loaded: 2515 / 5999
# Files loaded: 2516 / 5999
# Files loaded: 2517 / 5999
# Files loaded: 2518 / 5999
# Files loaded: 2519 / 5999
# Files loaded: 2520 / 5999
# Files loaded: 2521 / 5999
# Files loaded: 2522 / 5999
# Files loaded: 2523 / 5999
# Files loaded: 2524 / 5999
# Files loaded: 2525 / 5999
# Files loaded: 2526 / 5999
# Files loaded: 2527 / 5999
# Files loaded: 2528 / 5999
# Files loaded: 2529 / 5999
# Files loaded: 2530 / 5999
# Files loaded: 2531 / 5999
# Files loaded: 2532 / 5999
# Files loaded: 2533 / 5999
# Files loaded: 2534 / 5999
# Files loaded: 2535 / 5999
# Files loaded: 2536 / 5999
# Files loaded: 2537 / 5999
# Files loaded: 2538 / 5999
# Files loaded: 2539 / 5999
# Files loaded: 2540 / 5999
# Files loaded: 2541 / 5999
# Files loaded: 2542 / 5999
# Files loaded: 2543 / 5999
# Files loaded: 2544 / 5999
# Files loaded: 2545 / 5999
# Files loaded: 2546 / 5999
# Files loaded: 2547 / 5999
# Files loaded: 2548 / 5999
# Files loaded: 2549 / 5999
# Files loaded: 2550 / 5999
# Files loaded: 2551 / 5999
# Files loaded: 2552 / 5999
# Files loaded: 2553 / 5999
# Files loaded: 2554 / 5999
# Files loaded: 2555 / 5999
# Files loaded: 2556 / 5999
# Files loaded: 2557 / 5999
# Files loaded: 2558 / 5999
# Files loaded: 2559 / 5999
# Files loaded: 2560 / 5999
# Files loaded: 2561 / 5999
# Files loaded: 2562 / 5999
# Files loaded: 2563 / 5999
# Files loaded: 2564 / 5999
# Files loaded: 2565 / 5999
# Files loaded: 2566 / 5999
# Files loaded: 2567 / 5999
# Files loaded: 2568 / 5999
# Files loaded: 2569 / 5999
# Files loaded: 2570 / 5999
# Files loaded: 2571 / 5999
# Files loaded: 2572 / 5999
# Files loaded: 2573 / 5999
# Files loaded: 2574 / 5999
# Files loaded: 2575 / 5999
# Files loaded: 2576 / 5999
# Files loaded: 2577 / 5999
# Files loaded: 2578 / 5999
# Files loaded: 2579 / 5999
# Files loaded: 2580 / 5999
# Files loaded: 2581 / 5999
# Files loaded: 2582 / 5999
# Files loaded: 2583 / 5999
# Files loaded: 2584 / 5999
# Files loaded: 2585 / 5999
# Files loaded: 2586 / 5999
# Files loaded: 2587 / 5999
# Files loaded: 2588 / 5999
# Files loaded: 2589 / 5999
# Files loaded: 2590 / 5999
# Files loaded: 2591 / 5999
# Files loaded: 2592 / 5999
# Files loaded: 2593 / 5999
# Files loaded: 2594 / 5999
# Files loaded: 2595 / 5999
# Files loaded: 2596 / 5999
# Files loaded: 2597 / 5999
# Files loaded: 2598 / 5999
# Files loaded: 2599 / 5999
# Files loaded: 2600 / 5999
# Files loaded: 2601 / 5999
# Files loaded: 2602 / 5999
# Files loaded: 2603 / 5999
# Files loaded: 2604 / 5999
# Files loaded: 2605 / 5999
# Files loaded: 2606 / 5999
# Files loaded: 2607 / 5999
# Files loaded: 2608 / 5999
# Files loaded: 2609 / 5999
# Files loaded: 2610 / 5999
# Files loaded: 2611 / 5999
# Files loaded: 2612 / 5999
# Files loaded: 2613 / 5999
# Files loaded: 2614 / 5999
# Files loaded: 2615 / 5999
# Files loaded: 2616 / 5999
# Files loaded: 2617 / 5999
# Files loaded: 2618 / 5999
# Files loaded: 2619 / 5999
# Files loaded: 2620 / 5999
# Files loaded: 2621 / 5999
# Files loaded: 2622 / 5999
# Files loaded: 2623 / 5999
# Files loaded: 2624 / 5999
# Files loaded: 2625 / 5999
# Files loaded: 2626 / 5999
# Files loaded: 2627 / 5999
# Files loaded: 2628 / 5999
# Files loaded: 2629 / 5999
# Files loaded: 2630 / 5999
# Files loaded: 2631 / 5999
# Files loaded: 2632 / 5999
# Files loaded: 2633 / 5999
# Files loaded: 2634 / 5999
# Files loaded: 2635 / 5999
# Files loaded: 2636 / 5999
# Files loaded: 2637 / 5999
# Files loaded: 2638 / 5999
# Files loaded: 2639 / 5999
# Files loaded: 2640 / 5999
# Files loaded: 2641 / 5999
# Files loaded: 2642 / 5999
# Files loaded: 2643 / 5999
# Files loaded: 2644 / 5999
# Files loaded: 2645 / 5999
# Files loaded: 2646 / 5999
# Files loaded: 2647 / 5999
# Files loaded: 2648 / 5999
# Files loaded: 2649 / 5999
# Files loaded: 2650 / 5999
# Files loaded: 2651 / 5999
# Files loaded: 2652 / 5999
# Files loaded: 2653 / 5999
# Files loaded: 2654 / 5999
# Files loaded: 2655 / 5999
# Files loaded: 2656 / 5999
# Files loaded: 2657 / 5999
# Files loaded: 2658 / 5999
# Files loaded: 2659 / 5999
# Files loaded: 2660 / 5999
# Files loaded: 2661 / 5999
# Files loaded: 2662 / 5999
# Files loaded: 2663 / 5999
# Files loaded: 2664 / 5999
# Files loaded: 2665 / 5999
# Files loaded: 2666 / 5999
# Files loaded: 2667 / 5999
# Files loaded: 2668 / 5999
# Files loaded: 2669 / 5999
# Files loaded: 2670 / 5999
# Files loaded: 2671 / 5999
# Files loaded: 2672 / 5999
# Files loaded: 2673 / 5999
# Files loaded: 2674 / 5999
# Files loaded: 2675 / 5999
# Files loaded: 2676 / 5999
# Files loaded: 2677 / 5999
# Files loaded: 2678 / 5999
# Files loaded: 2679 / 5999
# Files loaded: 2680 / 5999
# Files loaded: 2681 / 5999
# Files loaded: 2682 / 5999
# Files loaded: 2683 / 5999
# Files loaded: 2684 / 5999
# Files loaded: 2685 / 5999
# Files loaded: 2686 / 5999
# Files loaded: 2687 / 5999
# Files loaded: 2688 / 5999
# Files loaded: 2689 / 5999
# Files loaded: 2690 / 5999
# Files loaded: 2691 / 5999
# Files loaded: 2692 / 5999
# Files loaded: 2693 / 5999
# Files loaded: 2694 / 5999
# Files loaded: 2695 / 5999
# Files loaded: 2696 / 5999
# Files loaded: 2697 / 5999
# Files loaded: 2698 / 5999
# Files loaded: 2699 / 5999
# Files loaded: 2700 / 5999
# Files loaded: 2701 / 5999
# Files loaded: 2702 / 5999
# Files loaded: 2703 / 5999
# Files loaded: 2704 / 5999
# Files loaded: 2705 / 5999
# Files loaded: 2706 / 5999
# Files loaded: 2707 / 5999
# Files loaded: 2708 / 5999
# Files loaded: 2709 / 5999
# Files loaded: 2710 / 5999
# Files loaded: 2711 / 5999
# Files loaded: 2712 / 5999
# Files loaded: 2713 / 5999
# Files loaded: 2714 / 5999
# Files loaded: 2715 / 5999
# Files loaded: 2716 / 5999
# Files loaded: 2717 / 5999
# Files loaded: 2718 / 5999
# Files loaded: 2719 / 5999
# Files loaded: 2720 / 5999
# Files loaded: 2721 / 5999
# Files loaded: 2722 / 5999
# Files loaded: 2723 / 5999
# Files loaded: 2724 / 5999
# Files loaded: 2725 / 5999
# Files loaded: 2726 / 5999
# Files loaded: 2727 / 5999
# Files loaded: 2728 / 5999
# Files loaded: 2729 / 5999
# Files loaded: 2730 / 5999
# Files loaded: 2731 / 5999
# Files loaded: 2732 / 5999
# Files loaded: 2733 / 5999
# Files loaded: 2734 / 5999
# Files loaded: 2735 / 5999
# Files loaded: 2736 / 5999
# Files loaded: 2737 / 5999
# Files loaded: 2738 / 5999
# Files loaded: 2739 / 5999
# Files loaded: 2740 / 5999
# Files loaded: 2741 / 5999
# Files loaded: 2742 / 5999
# Files loaded: 2743 / 5999
# Files loaded: 2744 / 5999
# Files loaded: 2745 / 5999
# Files loaded: 2746 / 5999
# Files loaded: 2747 / 5999
# Files loaded: 2748 / 5999
# Files loaded: 2749 / 5999
# Files loaded: 2750 / 5999
# Files loaded: 2751 / 5999
# Files loaded: 2752 / 5999
# Files loaded: 2753 / 5999
# Files loaded: 2754 / 5999
# Files loaded: 2755 / 5999
# Files loaded: 2756 / 5999
# Files loaded: 2757 / 5999
# Files loaded: 2758 / 5999
# Files loaded: 2759 / 5999
# Files loaded: 2760 / 5999
# Files loaded: 2761 / 5999
# Files loaded: 2762 / 5999
# Files loaded: 2763 / 5999
# Files loaded: 2764 / 5999
# Files loaded: 2765 / 5999
# Files loaded: 2766 / 5999
# Files loaded: 2767 / 5999
# Files loaded: 2768 / 5999
# Files loaded: 2769 / 5999
# Files loaded: 2770 / 5999
# Files loaded: 2771 / 5999
# Files loaded: 2772 / 5999
# Files loaded: 2773 / 5999
# Files loaded: 2774 / 5999
# Files loaded: 2775 / 5999
# Files loaded: 2776 / 5999
# Files loaded: 2777 / 5999
# Files loaded: 2778 / 5999
# Files loaded: 2779 / 5999
# Files loaded: 2780 / 5999
# Files loaded: 2781 / 5999
# Files loaded: 2782 / 5999
# Files loaded: 2783 / 5999
# Files loaded: 2784 / 5999
# Files loaded: 2785 / 5999
# Files loaded: 2786 / 5999
# Files loaded: 2787 / 5999
# Files loaded: 2788 / 5999
# Files loaded: 2789 / 5999
# Files loaded: 2790 / 5999
# Files loaded: 2791 / 5999
# Files loaded: 2792 / 5999
# Files loaded: 2793 / 5999
# Files loaded: 2794 / 5999
# Files loaded: 2795 / 5999
# Files loaded: 2796 / 5999
# Files loaded: 2797 / 5999
# Files loaded: 2798 / 5999
# Files loaded: 2799 / 5999
# Files loaded: 2800 / 5999
# Files loaded: 2801 / 5999
# Files loaded: 2802 / 5999
# Files loaded: 2803 / 5999
# Files loaded: 2804 / 5999
# Files loaded: 2805 / 5999
# Files loaded: 2806 / 5999
# Files loaded: 2807 / 5999
# Files loaded: 2808 / 5999
# Files loaded: 2809 / 5999
# Files loaded: 2810 / 5999
# Files loaded: 2811 / 5999
# Files loaded: 2812 / 5999
# Files loaded: 2813 / 5999
# Files loaded: 2814 / 5999
# Files loaded: 2815 / 5999
# Files loaded: 2816 / 5999
# Files loaded: 2817 / 5999
# Files loaded: 2818 / 5999
# Files loaded: 2819 / 5999
# Files loaded: 2820 / 5999
# Files loaded: 2821 / 5999
# Files loaded: 2822 / 5999
# Files loaded: 2823 / 5999
# Files loaded: 2824 / 5999
# Files loaded: 2825 / 5999
# Files loaded: 2826 / 5999
# Files loaded: 2827 / 5999
# Files loaded: 2828 / 5999
# Files loaded: 2829 / 5999
# Files loaded: 2830 / 5999
# Files loaded: 2831 / 5999
# Files loaded: 2832 / 5999
# Files loaded: 2833 / 5999
# Files loaded: 2834 / 5999
# Files loaded: 2835 / 5999
# Files loaded: 2836 / 5999
# Files loaded: 2837 / 5999
# Files loaded: 2838 / 5999
# Files loaded: 2839 / 5999
# Files loaded: 2840 / 5999
# Files loaded: 2841 / 5999
# Files loaded: 2842 / 5999
# Files loaded: 2843 / 5999
# Files loaded: 2844 / 5999
# Files loaded: 2845 / 5999
# Files loaded: 2846 / 5999
# Files loaded: 2847 / 5999
# ...
# Files loaded: 5387 / 5999
# Files loaded: 5388 / 5999
# Files loaded: 5389 / 5999
# Files loaded: 5390 / 5999
# Files loaded: 5391 / 5999
# Files loaded: 5392 / 5999
# Files loaded: 5393 / 5999
# Files loaded: 5394 / 5999
# Files loaded: 5395 / 5999
# Files loaded: 5396 / 5999
# Files loaded: 5397 / 5999
# Files loaded: 5398 / 5999
# Files loaded: 5399 / 5999
# Files loaded: 5400 / 5999
# Files loaded: 5401 / 5999
# Files loaded: 5402 / 5999
# Files loaded: 5403 / 5999
# Files loaded: 5404 / 5999
# Files loaded: 5405 / 5999
# Files loaded: 5406 / 5999
# Files loaded: 5407 / 5999
# Files loaded: 5408 / 5999
# Files loaded: 5409 / 5999
# Files loaded: 5410 / 5999
# Files loaded: 5411 / 5999
# Files loaded: 5412 / 5999
# Files loaded: 5413 / 5999
# Files loaded: 5414 / 5999
# Files loaded: 5415 / 5999
# Files loaded: 5416 / 5999
# Files loaded: 5417 / 5999
# Files loaded: 5418 / 5999
# Files loaded: 5419 / 5999
# Files loaded: 5420 / 5999
# Files loaded: 5421 / 5999
# Files loaded: 5422 / 5999
# Files loaded: 5423 / 5999
# Files loaded: 5424 / 5999
# Files loaded: 5425 / 5999
# Files loaded: 5426 / 5999
# Files loaded: 5427 / 5999
# Files loaded: 5428 / 5999
# Files loaded: 5429 / 5999
# Files loaded: 5430 / 5999
# Files loaded: 5431 / 5999
# Files loaded: 5432 / 5999
# Files loaded: 5433 / 5999
# Files loaded: 5434 / 5999
# Files loaded: 5435 / 5999
# Files loaded: 5436 / 5999
# Files loaded: 5437 / 5999
# Files loaded: 5438 / 5999
# Files loaded: 5439 / 5999
# Files loaded: 5440 / 5999
# Files loaded: 5441 / 5999
# Files loaded: 5442 / 5999
# Files loaded: 5443 / 5999
# Files loaded: 5444 / 5999
# Files loaded: 5445 / 5999
# Files loaded: 5446 / 5999
# Files loaded: 5447 / 5999
# Files loaded: 5448 / 5999
# Files loaded: 5449 / 5999
# Files loaded: 5450 / 5999
# Files loaded: 5451 / 5999
# Files loaded: 5452 / 5999
# Files loaded: 5453 / 5999
# Files loaded: 5454 / 5999
# Files loaded: 5455 / 5999
# Files loaded: 5456 / 5999
# Files loaded: 5457 / 5999
# Files loaded: 5458 / 5999
# Files loaded: 5459 / 5999
# Files loaded: 5460 / 5999
# Files loaded: 5461 / 5999
# Files loaded: 5462 / 5999
# Files loaded: 5463 / 5999
# Files loaded: 5464 / 5999
# Files loaded: 5465 / 5999
# Files loaded: 5466 / 5999
# Files loaded: 5467 / 5999
# Files loaded: 5468 / 5999
# Files loaded: 5469 / 5999
# Files loaded: 5470 / 5999
# Files loaded: 5471 / 5999
# Files loaded: 5472 / 5999
# Files loaded: 5473 / 5999
# Files loaded: 5474 / 5999
# Files loaded: 5475 / 5999
# Files loaded: 5476 / 5999
# Files loaded: 5477 / 5999
# Files loaded: 5478 / 5999
# Files loaded: 5479 / 5999
# Files loaded: 5480 / 5999
# Files loaded: 5481 / 5999
# Files loaded: 5482 / 5999
# Files loaded: 5483 / 5999
# Files loaded: 5484 / 5999
# Files loaded: 5485 / 5999
# Files loaded: 5486 / 5999
# Files loaded: 5487 / 5999
# Files loaded: 5488 / 5999
# Files loaded: 5489 / 5999
# Files loaded: 5490 / 5999
# Files loaded: 5491 / 5999
# Files loaded: 5492 / 5999
# Files loaded: 5493 / 5999
# Files loaded: 5494 / 5999
# Files loaded: 5495 / 5999
# Files loaded: 5496 / 5999
# Files loaded: 5497 / 5999
# Files loaded: 5498 / 5999
# Files loaded: 5499 / 5999
# Files loaded: 5500 / 5999
# Files loaded: 5501 / 5999
# Files loaded: 5502 / 5999
# Files loaded: 5503 / 5999
# Files loaded: 5504 / 5999
# Files loaded: 5505 / 5999
# Files loaded: 5506 / 5999
# Files loaded: 5507 / 5999
# Files loaded: 5508 / 5999
# Files loaded: 5509 / 5999
# Files loaded: 5510 / 5999
# Files loaded: 5511 / 5999
# Files loaded: 5512 / 5999
# Files loaded: 5513 / 5999
# Files loaded: 5514 / 5999
# Files loaded: 5515 / 5999
# Files loaded: 5516 / 5999
# Files loaded: 5517 / 5999
# Files loaded: 5518 / 5999
# Files loaded: 5519 / 5999
# Files loaded: 5520 / 5999
# Files loaded: 5521 / 5999
# Files loaded: 5522 / 5999
# Files loaded: 5523 / 5999
# Files loaded: 5524 / 5999
# Files loaded: 5525 / 5999
# Files loaded: 5526 / 5999
# Files loaded: 5527 / 5999
# Files loaded: 5528 / 5999
# Files loaded: 5529 / 5999
# Files loaded: 5530 / 5999
# Files loaded: 5531 / 5999
# Files loaded: 5532 / 5999
# Files loaded: 5533 / 5999
# Files loaded: 5534 / 5999
# Files loaded: 5535 / 5999
# Files loaded: 5536 / 5999
# Files loaded: 5537 / 5999
# Files loaded: 5538 / 5999
# Files loaded: 5539 / 5999
# Files loaded: 5540 / 5999
# Files loaded: 5541 / 5999
# Files loaded: 5542 / 5999
# Files loaded: 5543 / 5999
# Files loaded: 5544 / 5999
# Files loaded: 5545 / 5999
# Files loaded: 5546 / 5999
# Files loaded: 5547 / 5999
# Files loaded: 5548 / 5999
# Files loaded: 5549 / 5999
# Files loaded: 5550 / 5999
# Files loaded: 5551 / 5999
# Files loaded: 5552 / 5999
# Files loaded: 5553 / 5999
# Files loaded: 5554 / 5999
# Files loaded: 5555 / 5999
# Files loaded: 5556 / 5999
# Files loaded: 5557 / 5999
# Files loaded: 5558 / 5999
# Files loaded: 5559 / 5999
# Files loaded: 5560 / 5999
# Files loaded: 5561 / 5999
# Files loaded: 5562 / 5999
# Files loaded: 5563 / 5999
# Files loaded: 5564 / 5999
# Files loaded: 5565 / 5999
# Files loaded: 5566 / 5999
# Files loaded: 5567 / 5999
# Files loaded: 5568 / 5999
# Files loaded: 5569 / 5999
# Files loaded: 5570 / 5999
# Files loaded: 5571 / 5999
# Files loaded: 5572 / 5999
# Files loaded: 5573 / 5999
# Files loaded: 5574 / 5999
# Files loaded: 5575 / 5999
# Files loaded: 5576 / 5999
# Files loaded: 5577 / 5999
# Files loaded: 5578 / 5999
# Files loaded: 5579 / 5999
# Files loaded: 5580 / 5999
# Files loaded: 5581 / 5999
# Files loaded: 5582 / 5999
# Files loaded: 5583 / 5999
# Files loaded: 5584 / 5999
# Files loaded: 5585 / 5999
# Files loaded: 5586 / 5999
# Files loaded: 5587 / 5999
# Files loaded: 5588 / 5999
# Files loaded: 5589 / 5999
# Files loaded: 5590 / 5999
# Files loaded: 5591 / 5999
# Files loaded: 5592 / 5999
# Files loaded: 5593 / 5999
# Files loaded: 5594 / 5999
# Files loaded: 5595 / 5999
# Files loaded: 5596 / 5999
# Files loaded: 5597 / 5999
# Files loaded: 5598 / 5999
# Files loaded: 5599 / 5999
# Files loaded: 5600 / 5999
# Files loaded: 5601 / 5999
# Files loaded: 5602 / 5999
# Files loaded: 5603 / 5999
# Files loaded: 5604 / 5999
# Files loaded: 5605 / 5999
# Files loaded: 5606 / 5999
# Files loaded: 5607 / 5999
# Files loaded: 5608 / 5999
# Files loaded: 5609 / 5999
# Files loaded: 5610 / 5999
# Files loaded: 5611 / 5999
# Files loaded: 5612 / 5999
# Files loaded: 5613 / 5999
# Files loaded: 5614 / 5999
# Files loaded: 5615 / 5999
# Files loaded: 5616 / 5999
# Files loaded: 5617 / 5999
# Files loaded: 5618 / 5999
# Files loaded: 5619 / 5999
# Files loaded: 5620 / 5999
# Files loaded: 5621 / 5999
# Files loaded: 5622 / 5999
# Files loaded: 5623 / 5999
# Files loaded: 5624 / 5999
# Files loaded: 5625 / 5999
# Files loaded: 5626 / 5999
# Files loaded: 5627 / 5999
# Files loaded: 5628 / 5999
# Files loaded: 5629 / 5999
# Files loaded: 5630 / 5999
# Files loaded: 5631 / 5999
# Files loaded: 5632 / 5999
# Files loaded: 5633 / 5999
# Files loaded: 5634 / 5999
# Files loaded: 5635 / 5999
# Files loaded: 5636 / 5999
# Files loaded: 5637 / 5999
# Files loaded: 5638 / 5999
# Files loaded: 5639 / 5999
# Files loaded: 5640 / 5999
# Files loaded: 5641 / 5999
# Files loaded: 5642 / 5999
# Files loaded: 5643 / 5999
# Files loaded: 5644 / 5999
# Files loaded: 5645 / 5999
# Files loaded: 5646 / 5999
# Files loaded: 5647 / 5999
# Files loaded: 5648 / 5999
# Files loaded: 5649 / 5999
# Files loaded: 5650 / 5999
# Files loaded: 5651 / 5999
# Files loaded: 5652 / 5999
# Files loaded: 5653 / 5999
# Files loaded: 5654 / 5999
# Files loaded: 5655 / 5999
# Files loaded: 5656 / 5999
# Files loaded: 5657 / 5999
# Files loaded: 5658 / 5999
# Files loaded: 5659 / 5999
# Files loaded: 5660 / 5999
# Files loaded: 5661 / 5999
# Files loaded: 5662 / 5999
# Files loaded: 5663 / 5999
# Files loaded: 5664 / 5999
# Files loaded: 5665 / 5999
# Files loaded: 5666 / 5999
# Files loaded: 5667 / 5999
# Files loaded: 5668 / 5999
# Files loaded: 5669 / 5999
# Files loaded: 5670 / 5999
# Files loaded: 5671 / 5999
# Files loaded: 5672 / 5999
# Files loaded: 5673 / 5999
# Files loaded: 5674 / 5999
# Files loaded: 5675 / 5999
# Files loaded: 5676 / 5999
# Files loaded: 5677 / 5999
# Files loaded: 5678 / 5999
# Files loaded: 5679 / 5999
# Files loaded: 5680 / 5999
# Files loaded: 5681 / 5999
# Files loaded: 5682 / 5999
# Files loaded: 5683 / 5999
# Files loaded: 5684 / 5999
# Files loaded: 5685 / 5999
# Files loaded: 5686 / 5999
# Files loaded: 5687 / 5999
# Files loaded: 5688 / 5999
# Files loaded: 5689 / 5999
# Files loaded: 5690 / 5999
# Files loaded: 5691 / 5999
# Files loaded: 5692 / 5999
# Files loaded: 5693 / 5999
# Files loaded: 5694 / 5999
# Files loaded: 5695 / 5999
# Files loaded: 5696 / 5999
# Files loaded: 5697 / 5999
# Files loaded: 5698 / 5999
# Files loaded: 5699 / 5999
# Files loaded: 5700 / 5999
# Files loaded: 5701 / 5999
# Files loaded: 5702 / 5999
# Files loaded: 5703 / 5999
# Files loaded: 5704 / 5999
# Files loaded: 5705 / 5999
# Files loaded: 5706 / 5999
# Files loaded: 5707 / 5999
# Files loaded: 5708 / 5999
# Files loaded: 5709 / 5999
# Files loaded: 5710 / 5999
# Files loaded: 5711 / 5999
# Files loaded: 5712 / 5999
# Files loaded: 5713 / 5999
# Files loaded: 5714 / 5999
# Files loaded: 5715 / 5999
# Files loaded: 5716 / 5999
# Files loaded: 5717 / 5999
# Files loaded: 5718 / 5999
# Files loaded: 5719 / 5999
# Files loaded: 5720 / 5999
# Files loaded: 5721 / 5999
# Files loaded: 5722 / 5999
# Files loaded: 5723 / 5999
# Files loaded: 5724 / 5999
# Files loaded: 5725 / 5999
# Files loaded: 5726 / 5999
# Files loaded: 5727 / 5999
# Files loaded: 5728 / 5999
# Files loaded: 5729 / 5999
# Files loaded: 5730 / 5999
# Files loaded: 5731 / 5999
# Files loaded: 5732 / 5999
# Files loaded: 5733 / 5999
# Files loaded: 5734 / 5999
# Files loaded: 5735 / 5999
# Files loaded: 5736 / 5999
# Files loaded: 5737 / 5999
# Files loaded: 5738 / 5999
# Files loaded: 5739 / 5999
# Files loaded: 5740 / 5999
# Files loaded: 5741 / 5999
# Files loaded: 5742 / 5999
# Files loaded: 5743 / 5999
# Files loaded: 5744 / 5999
# Files loaded: 5745 / 5999
# Files loaded: 5746 / 5999
# Files loaded: 5747 / 5999
# Files loaded: 5748 / 5999
# Files loaded: 5749 / 5999
# Files loaded: 5750 / 5999
# Files loaded: 5751 / 5999
# Files loaded: 5752 / 5999
# Files loaded: 5753 / 5999
# Files loaded: 5754 / 5999
# Files loaded: 5755 / 5999
# Files loaded: 5756 / 5999
# Files loaded: 5757 / 5999
# Files loaded: 5758 / 5999
# Files loaded: 5759 / 5999
# Files loaded: 5760 / 5999
# Files loaded: 5761 / 5999
# Files loaded: 5762 / 5999
# Files loaded: 5763 / 5999
# Files loaded: 5764 / 5999
# Files loaded: 5765 / 5999
# Files loaded: 5766 / 5999
# Files loaded: 5767 / 5999
# Files loaded: 5768 / 5999
# Files loaded: 5769 / 5999
# Files loaded: 5770 / 5999
# Files loaded: 5771 / 5999
# Files loaded: 5772 / 5999
# Files loaded: 5773 / 5999
# Files loaded: 5774 / 5999
# Files loaded: 5775 / 5999
# Files loaded: 5776 / 5999
# Files loaded: 5777 / 5999
# Files loaded: 5778 / 5999
# Files loaded: 5779 / 5999
# Files loaded: 5780 / 5999
# Files loaded: 5781 / 5999
# Files loaded: 5782 / 5999
# Files loaded: 5783 / 5999
# Files loaded: 5784 / 5999
# Files loaded: 5785 / 5999
# Files loaded: 5786 / 5999
# Files loaded: 5787 / 5999
# Files loaded: 5788 / 5999
# Files loaded: 5789 / 5999
# Files loaded: 5790 / 5999
# Files loaded: 5791 / 5999
# Files loaded: 5792 / 5999
# Files loaded: 5793 / 5999
# Files loaded: 5794 / 5999
# Files loaded: 5795 / 5999
# Files loaded: 5796 / 5999
# Files loaded: 5797 / 5999
# Files loaded: 5798 / 5999
# Files loaded: 5799 / 5999
# Files loaded: 5800 / 5999
# Files loaded: 5801 / 5999
# Files loaded: 5802 / 5999
# Files loaded: 5803 / 5999
# Files loaded: 5804 / 5999
# Files loaded: 5805 / 5999
# Files loaded: 5806 / 5999
# Files loaded: 5807 / 5999
# Files loaded: 5808 / 5999
# Files loaded: 5809 / 5999
# Files loaded: 5810 / 5999
# Files loaded: 5811 / 5999
# Files loaded: 5812 / 5999
# Files loaded: 5813 / 5999
# Files loaded: 5814 / 5999
# Files loaded: 5815 / 5999
# Files loaded: 5816 / 5999
# Files loaded: 5817 / 5999
# Files loaded: 5818 / 5999
# Files loaded: 5819 / 5999
# Files loaded: 5820 / 5999
# Files loaded: 5821 / 5999
# Files loaded: 5822 / 5999
# Files loaded: 5823 / 5999
# Files loaded: 5824 / 5999
# Files loaded: 5825 / 5999
# Files loaded: 5826 / 5999
# Files loaded: 5827 / 5999
# Files loaded: 5828 / 5999
# Files loaded: 5829 / 5999
# Files loaded: 5830 / 5999
# Files loaded: 5831 / 5999
# Files loaded: 5832 / 5999
# Files loaded: 5833 / 5999
# Files loaded: 5834 / 5999
# Files loaded: 5835 / 5999
# Files loaded: 5836 / 5999
# Files loaded: 5837 / 5999
# Files loaded: 5838 / 5999
# Files loaded: 5839 / 5999
# Files loaded: 5840 / 5999
# Files loaded: 5841 / 5999
# Files loaded: 5842 / 5999
# Files loaded: 5843 / 5999
# Files loaded: 5844 / 5999
# Files loaded: 5845 / 5999
# Files loaded: 5846 / 5999
# Files loaded: 5847 / 5999
# Files loaded: 5848 / 5999
# Files loaded: 5849 / 5999
# Files loaded: 5850 / 5999
# Files loaded: 5851 / 5999
# Files loaded: 5852 / 5999
# Files loaded: 5853 / 5999
# Files loaded: 5854 / 5999
# Files loaded: 5855 / 5999
# Files loaded: 5856 / 5999
# Files loaded: 5857 / 5999
# Files loaded: 5858 / 5999
# Files loaded: 5859 / 5999
# Files loaded: 5860 / 5999
# Files loaded: 5861 / 5999
# Files loaded: 5862 / 5999
# Files loaded: 5863 / 5999
# Files loaded: 5864 / 5999
# Files loaded: 5865 / 5999
# Files loaded: 5866 / 5999
# Files loaded: 5867 / 5999
# Files loaded: 5868 / 5999
# Files loaded: 5869 / 5999
# Files loaded: 5870 / 5999
# Files loaded: 5871 / 5999
# Files loaded: 5872 / 5999
# Files loaded: 5873 / 5999
# Files loaded: 5874 / 5999
# Files loaded: 5875 / 5999
# Files loaded: 5876 / 5999
# Files loaded: 5877 / 5999
# Files loaded: 5878 / 5999
# Files loaded: 5879 / 5999
# Files loaded: 5880 / 5999
# Files loaded: 5881 / 5999
# Files loaded: 5882 / 5999
# Files loaded: 5883 / 5999
# Files loaded: 5884 / 5999
# Files loaded: 5885 / 5999
# Files loaded: 5886 / 5999
# Files loaded: 5887 / 5999
# Files loaded: 5888 / 5999
# Files loaded: 5889 / 5999
# Files loaded: 5890 / 5999
# Files loaded: 5891 / 5999
# Files loaded: 5892 / 5999
# Files loaded: 5893 / 5999
# Files loaded: 5894 / 5999
# Files loaded: 5895 / 5999
# Files loaded: 5896 / 5999
# Files loaded: 5897 / 5999
# Files loaded: 5898 / 5999
# Files loaded: 5899 / 5999
# Files loaded: 5900 / 5999
# Files loaded: 5901 / 5999
# Files loaded: 5902 / 5999
# Files loaded: 5903 / 5999
# Files loaded: 5904 / 5999
# Files loaded: 5905 / 5999
# Files loaded: 5906 / 5999
# Files loaded: 5907 / 5999
# Files loaded: 5908 / 5999
# Files loaded: 5909 / 5999
# Files loaded: 5910 / 5999
# Files loaded: 5911 / 5999
# Files loaded: 5912 / 5999
# Files loaded: 5913 / 5999
# Files loaded: 5914 / 5999
# Files loaded: 5915 / 5999
# Files loaded: 5916 / 5999
# Files loaded: 5917 / 5999
# Files loaded: 5918 / 5999
# Files loaded: 5919 / 5999
# Files loaded: 5920 / 5999
# Files loaded: 5921 / 5999
# Files loaded: 5922 / 5999
# Files loaded: 5923 / 5999
# Files loaded: 5924 / 5999
# Files loaded: 5925 / 5999
# Files loaded: 5926 / 5999
# Files loaded: 5927 / 5999
# Files loaded: 5928 / 5999
# Files loaded: 5929 / 5999
# Files loaded: 5930 / 5999
# Files loaded: 5931 / 5999
# Files loaded: 5932 / 5999
# Files loaded: 5933 / 5999
# Files loaded: 5934 / 5999
# Files loaded: 5935 / 5999
# Files loaded: 5936 / 5999
# Files loaded: 5937 / 5999
# Files loaded: 5938 / 5999
# Files loaded: 5939 / 5999
# Files loaded: 5940 / 5999
# Files loaded: 5941 / 5999
# Files loaded: 5942 / 5999
# Files loaded: 5943 / 5999
# Files loaded: 5944 / 5999
# Files loaded: 5945 / 5999
# Files loaded: 5946 / 5999
# Files loaded: 5947 / 5999
# Files loaded: 5948 / 5999
# Files loaded: 5949 / 5999
# Files loaded: 5950 / 5999
# Files loaded: 5951 / 5999
# Files loaded: 5952 / 5999
# Files loaded: 5953 / 5999
# Files loaded: 5954 / 5999
# Files loaded: 5955 / 5999
# Files loaded: 5956 / 5999
# Files loaded: 5957 / 5999
# Files loaded: 5958 / 5999
# Files loaded: 5959 / 5999
# Files loaded: 5960 / 5999
# Files loaded: 5961 / 5999
# Files loaded: 5962 / 5999
# Files loaded: 5963 / 5999
# Files loaded: 5964 / 5999
# Files loaded: 5965 / 5999
# Files loaded: 5966 / 5999
# Files loaded: 5967 / 5999
# Files loaded: 5968 / 5999
# Files loaded: 5969 / 5999
# Files loaded: 5970 / 5999
# Files loaded: 5971 / 5999
# Files loaded: 5972 / 5999
# Files loaded: 5973 / 5999
# Files loaded: 5974 / 5999
# Files loaded: 5975 / 5999
# Files loaded: 5976 / 5999
# Files loaded: 5977 / 5999
# Files loaded: 5978 / 5999
# Files loaded: 5979 / 5999
# Files loaded: 5980 / 5999
# Files loaded: 5981 / 5999
# Files loaded: 5982 / 5999
# Files loaded: 5983 / 5999
# Files loaded: 5984 / 5999
# Files loaded: 5985 / 5999
# Files loaded: 5986 / 5999
# Files loaded: 5987 / 5999
# Files loaded: 5988 / 5999
# Files loaded: 5989 / 5999
# Files loaded: 5990 / 5999
# Files loaded: 5991 / 5999
# Files loaded: 5992 / 5999
# Files loaded: 5993 / 5999
# Files loaded: 5994 / 5999
# Files loaded: 5995 / 5999
# Files loaded: 5996 / 5999
# Files loaded: 5997 / 5999
# Files loaded: 5998 / 5999
# Files loaded: 5999 / 5999
# Features shape: (5999, 1280)
# Labels shape: (5999,)

# %%
import numpy as np

# Load features from the saved numpy file
features = np.load("/content/drive/MyDrive/datasets/features.npy")

# Now you can access the shape of the features array
print("Features shape:", features.shape)
# Out:
# Features shape: (5999, 1280)

# %%
import numpy as np

# Load features from the saved numpy file
labels = np.load("/content/drive/MyDrive/datasets/labels.npy")

# Now you can access the shape of the features array
print("labels shape:", labels.shape)
# Out:
# labels shape: (5999,)

# %%
# Define your classes list and dataset directory
classes_list = ['arrhythmia_preprocessed', 'atrial_preprocessed', 'supra_preprocessed']

# %%
# Reshape features array to add a dummy time dimension
num_samples, num_features = features.shape
num_timesteps = 1  # Add a dummy time dimension

features_reshaped = features.reshape(num_samples, num_timesteps, num_features)

# %%
# Print the new shape
print("Features reshaped:", features_reshaped.shape)
# Out:
# Features reshaped: (5999, 1, 1280)

# %%
# Define input shape and number of classes
input_shape = features_reshaped.shape[1:]  # Shape is (1, 1280)
num_classes = len(classes_list)

# %%
# Define the input shape
input_shape = (1, 1280)

# Define the number of classes
num_classes = 3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_reshaped, labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4799, 1, 1280)
# (1200, 1, 1280)
# (4799,)
# (1200,)

# %%
import numpy as np

# Remove any extra singleton dimensions
X_train_reshaped = np.squeeze(X_train, axis=1)
X_test_reshaped = np.squeeze(X_test, axis=1)

# %%
print(X_train_reshaped.shape)
print(X_test_reshaped.shape)
# Out:
# (4799, 1280)
# (1200, 1280)

# %%
# Define your Conv1D model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(1280,1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # Adjust output units based on your number of classes

# %%
# Compile your model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train your model
model.fit(X_train_reshaped, y_train, epochs=2, batch_size=32, validation_data=(X_test_reshaped, y_test), verbose=1)
# Out:
# Epoch 1/2
# 150/150 [==============================] - 14s 89ms/step - loss: 0.6786 - accuracy: 0.6662 - val_loss: 0.4567 - val_accuracy: 0.7517
# Epoch 2/2
# 150/150 [==============================] - 10s 70ms/step - loss: 0.3229 - accuracy: 0.8631 - val_loss: 0.3515 - val_accuracy: 0.8517

# %%
# Evaluate your model
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 38/38 [==============================] - 1s 14ms/step - loss: 0.3515 - accuracy: 0.8517
# Test Loss: 0.3515091836452484
# Test Accuracy: 0.8516666889190674

# %%
# Save the model to H5 file
model.save("your_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict classes for test data
y_pred = np.argmax(model.predict(X_test_reshaped), axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
# Out:
# 38/38 [==============================] - 1s 15ms/step

# %%
print(y_pred)
# Out:
# [0 1 2 ... 1 2 1]

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Class 0', 'Class 1', 'Class 2'],
            yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
def load_next_atrial_samples(num_samples):
    atrial_features = []
    atrial_labels = []

    # Define the target number of files to load for the atrial class
    target_num_files = num_samples

    total_files_loaded = 0

    class_name = 'atrial_preprocessed'  # Atrial class

    class_files_list = os.listdir(os.path.join(datasetDir, class_name))

    # Skip the files that have already been loaded
    class_files_list = class_files_list[2000:]

    for file_index, file_name in enumerate(class_files_list, start=1):
        if total_files_loaded >= target_num_files:
            break

        signal_file_path = os.path.join(datasetDir, class_name, file_name)
        array_data = np.load(signal_file_path)

        atrial_features.append(array_data)
        atrial_labels.append(1)  # Assuming atrial class label is 1

        total_files_loaded += 1

    atrial_features = np.asarray(atrial_features)
    atrial_labels = np.asarray(atrial_labels)

    return atrial_features, atrial_labels

# Load the next 2000 samples for the atrial class
atrial_features, atrial_labels = load_next_atrial_samples(num_samples=2000)

# Now you can use atrial_features and atrial_labels to train a model specifically for the next 2000 samples of the atrial class.

# %%
import tkinter as tk
from tkinter import filedialog
import numpy as np
import tensorflow as tf
import scipy.signal as sg

# Load your trained model
model = tf.keras.models.load_model("your_model.h5")

# %%
classes = ['supraventricular_arrhythmia', 'atrial', 'arrhythmia']  # Replace with your class names

# %%
# Function to preprocess the input signal for all classes
def preprocessing(input_signal, class_index):
    # Split the input signal into blocks
    block_size = 1280
    num_blocks = len(input_signal) // block_size

    processed_data = []

    for i in range(num_blocks):
        block_start = i * block_size
        block_end = (i + 1) * block_size
        block = input_signal[block_start:block_end]

        # Mean removal
        block = block - np.mean(block)

        # Low-pass filtering
        block = sg.filtfilt(*sg.butter(4, 0.9, btype='low'), block)

        # High-pass filtering (baseline wander removal)
        block = sg.filtfilt(*sg.butter(4, 0.0039, btype='high'), block)

        # Normalization
        block = block / np.max(np.abs(block))

        processed_data.append(block)

    return np.array(processed_data), class_index

# %%
# Function to classify the input signal for all classes
def classify_signal(input_signal):
    # Preprocess the input signal
    processed_signal, _ = preprocessing(input_signal, class_index=None)  # Assuming class_index is not used in classification

    # Predict the class using the trained model
    prediction = model.predict(processed_signal)

    # Get the predicted class label for each block
    predicted_class_indices = np.argmax(prediction, axis=1)

    # Get the majority predicted class index
    predicted_class_index = np.bincount(predicted_class_indices).argmax()

    # Get the predicted class label
    predicted_class = classes[predicted_class_index]

    return predicted_class

# %%
from google.colab import files
import numpy as np
import tensorflow as tf
import scipy.signal as sg

# %%
# Function to handle file upload and classify the uploaded files
def handle_file_upload(b):
    uploaded = files.upload()
    if uploaded:
        for file_name in uploaded.keys():
            # Read the uploaded file and extract the signal
            with open(file_name, 'rb') as file:
                input_signal = np.fromfile(file, dtype=np.float32)

            # Classify the signal
            predicted_class = classify_signal(input_signal)

            # Print the predicted class
            print("Predicted Class:", predicted_class)

# %%
# !pip install ipywidgets
import ipywidgets as widgets
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1

# %%
# Create a file upload button
upload_button = widgets.Button(description="Choose .dat File")
upload_button.on_click(handle_file_upload)
display(upload_button)
